# %%
import cloud.serialization.cloudpickle as pickle
# Out:
# DEBUG:Cloud:Log file (/home/amir/.picloud/cloud.log) opened

# %% [markdown]
# # Sort the taxonomy in a dictionary

# %%
# This depends on the order of the lines
# This script needs the unique format of taxonomy.csv
# An alternative for a script aimed at a more sensible format 
# follows

taxonomy_file_lines = open('data/taxonomy.csv','r').readlines()

taxonomy = {}

current_phylum=None
current_group = None
current_genus = None

for line in [l for l in taxonomy_file_lines if not 'group' in l]:
    part = line.rstrip('\n').split('\t')
    
    # first value is phylum.
    # It applies to all subsequent lines 
    # until there is a new line with a first value
    if part[0]:
        current_phylum = part[0]
        taxonomy[current_phylum] = {}
        
    # second value is 'group' (order, super family or family)
    # it applies to all subsequent lines
    # until there is a new line with second value
    elif part[1]:
        current_group = part[1]
        taxonomy[current_phylum][current_group] = {}
           
    # third value is genus if there is no fourth value
    # it applies to all subsequent lines 
    # until there is a new line with third value and no forth value   
    elif part[2] and not part[3]:
        current_genus = part[2]
        if current_group in taxonomy[current_phylum].keys():
            taxonomy[current_phylum][current_group][current_genus] = []
        else:
            current_group = 'unspecified'
            if not current_group in taxonomy[current_phylum].keys():
                taxonomy[current_phylum][current_group] = {}
            taxonomy[current_phylum][current_group][current_genus] = []
    
    # If there are both third and forth values, it is a species
    # it belongs to the latest identifed genus
    elif part[2] and part[3]:
        sp = "%s %s"%(part[2], part[3])
        taxonomy[current_phylum][current_group][current_genus].append(sp)
        
# pickle file
pickle_file_name = 'data/taxonomy.pkl'
output = open(pickle_file_name,'wb')
pickle.dump(taxonomy, output)
output.close()

# text file
tax = open('data/taxonomy_dict.txt','wt')
tax.write(str(taxonomy))
tax.close()

# %% [markdown]
# ## Alternative - Sort the taxonomy in a dictionary
# I did not use this script, it is aimed at a more sensible input format than the one I had above. It expects one line per species, containing four levels of taxonomy and blanks when the level is skipped. Exampe:
#
# <pre>
# Amphipoda<font color=red>\tCorophiidae\t</font>Corophium\tCorophium curvispinum\n
# Amphipoda<font color=red>\tCorophiidae\t</font>Corophium\tCorophium insidiosum\n
# Crangonyctidae<font color=red>\t\t</font>Crangonyx\tCrangonyx pseudogracilis\n
# Crangonyctidae<font color=red>\t\t</font>Crangonyx\tCrangonyx subterraneus\n
# </pre>

# %%
# This is just an example, I never ran this, may need debugging
# or may need to be costumized

taxonomy_file_lines = open('some_file.tsv','r').readlines()

taxonomy = {}

for line in taxonomy_file_lines:
    
    parts = line.rstrip().split('\t')
    hi_group = parts[0]
    lo_group = parts[1]
    genus = parts[2]
    species = parts[3]
    
    if not hi_group in taxonomy.keys():
        taxonomy[hi_group] = {}
    if lo_group and not lo_group in taxonomy[hi_group].keys():
        taxonomy[hi_group][lo_group] = {}
    if lo_group and not genus in taxonomy[hi_group][lo_group].keys():
        taxonomy[hi_group][lo_group][genus] = []
    if not lo_group and not genus in taxonomy[hi_group].keys():
        taxonomy[hi_group][genus] = []
    if lo_group:
        taxonomy[hi_group][lo_group][genus].append(species)
    else:
        taxonomy[hi_group][genus].append(species)

# %%
taxonomy
# Out:
# {'Acanthocephala': {},
#  'Amphipoda': {'Corophiidae': {'Corophium': ['Corophium curvispinum',
#     'Corophium insidiosum',
#     'Corophium lacustre',
#     'Corophium multisetosum',
#     'Corophium volutator']},
#   'Crangonyctidae': {'Crangonyx': ['Crangonyx pseudogracilis',
#     'Crangonyx subterraneus']},
#   'Gammaridae': {'Dikerogammarus': ['Dikerogammarus villosus'],
#    'Echinogammarus': ['Echinogammarus berilloni'],
#    'Gammarus': ['Gammarus chevreuxi',
#     'Gammarus duebeni',
#     'Gammarus lacustris',
#     'Gammarus locusta',
#     'Gammarus oceanicus',
#     'Gammarus pulex',
#     'Gammarus salinus',
#     'Gammarus tigrinus',
#     'Gammarus zaddachi']},
#   'Gammaridae (including Crangonyctidae and Niphargidae)': {},
#   'Gammaroidea': {},
#   'Niphargidae': {'Microniphargus': ['Microniphargus leruthi'],
#    'Niphargus': ['Niphargus aquilex',
#     'Niphargus fontanus',
#     'Niphargus kochianus',
#     'Niphargus wexfordensis',
#     'Niphargus glenniei']},
#   'Talitridae': {'Orchestia': ['Orchestia cavimana']}},
#  'Anostraca': {'unspecified': {'Artemia': ['Artemia salina'],
#    'Chirocephalus': ['Chirocephalus diaphanus']}},
#  'Aphanoneura': {'Aeolosomatida': {},
#   'Aeolosomatidae': {'Aeolosoma': ['Aeolosoma beddardi',
#     'Aeolosoma headleyi',
#     'Aeolosoma hemprichi',
#     'Aeolosoma quaternarium',
#     'Aeolosoma tenebrarum',
#     'Aeolosoma variegatum']}},
#  'Araneae': {'unspecified': {'Argyroneta': ['Argyroneta aquatica']}},
#  'Bathynellacea': {'unspecified': {'Antrobathynella': ['Antrobathynella stammeri'],
#    'Bathynella': ['Bathynella natans']}},
#  'Bivalvia': {'Anodontinae': {},
#   'Corbiculidae': {'Corbicula': ['Corbicula fluminea']},
#   'Dreissenidae': {'Dreissena': ['Dreissena polymorpha'],
#    'Mytilopsis': ['Mytilopsis leucophaeata']},
#   'Heterodonta': {},
#   'Margaritiferidae': {'Margaritifera': ['Margaritifera margaritifera']},
#   'Pelecypodia': {},
#   'Sphaeriidae': {'Musculium': ['Musculium lacustre', 'Musculium transversum'],
#    'Pisidium': ['Pisidium amnicum',
#     'Pisidium casertanum',
#     'Pisidium conventus',
#     'Pisidium henslowanum',
#     'Pisidium hibernicum',
#     'Pisidium lilljeborgii',
#     'Pisidium milium',
#     'Pisidium moitessierianum',
#     'Pisidium nitidum',
#     'Pisidium obtusale',
#     'Pisidium personatum',
#     'Pisidium pseudosphaerium',
#     'Pisidium pulchellum',
#     'Pisidium subtruncatum',
#     'Pisidium supinum',
#     'Pisidium tenuilineatum'],
#    'Sphaerium': ['Sphaerium corneum',
#     'Sphaerium rivicola',
#     'Sphaerium solidum',
#     'Sphaerium nucleus']},
#   'Unionidae': {'Anodonta': ['Anodonta anatina',
#     'Anodonta cygnea',
#     'Anodonta woodiana'],
#    'Pseudanodonta': ['Pseudanodonta complanata'],
#    'Unio': ['Unio pictorum', 'Unio tumidus']}},
#  'Branchiobdellida': {'unspecified': {'Branchiobdella': ['Branchiobdella astaci']}},
#  'Branchiura': {'unspecified': {'Argulus': ['Argulus coregoni',
#     'Argulus foliaceus']}},
#  'Cestoidea': {},
#  'Chilopoda': {'Geophilidae': {'Strigamia': ['Strigamia maritima']},
#   'Geophilomorpha': {}},
#  'Cladocera': {'Acantholeberidae': {'Acantholeberis ': ['Acantholeberis  curvirostris']},
#   'Anomopoda': {},
#   'Bosminidae': {'Bosmina ': ['Bosmina  coregoni',
#     'Bosmina  longirostris',
#     'Bosmina  longispina']},
#   'Cercopagidae': {'Bythotrephes ': ['Bythotrephes  longimanus']},
#   'Chydoridae': {'Acroperus ': ['Acroperus  harpae', 'Acroperus  angustatus'],
#    'Alona ': ['Alona  affinis',
#     'Alona  costata',
#     'Alona  elegans',
#     'Alona  guttata',
#     'Alona  intermedia',
#     'Alona  karelica',
#     'Alona  quadrangularis',
#     'Alona  rustica',
#     'Alona  weltneri'],
#    'Alonella ': ['Alonella  excisa', 'Alonella  exigua', 'Alonella  nana'],
#    'Alonopsis ': ['Alonopsis  elongata'],
#    'Anchistropus ': ['Anchistropus  emarginatus'],
#    'Camptocercus ': ['Camptocercus  lilljeborgi',
#     'Camptocercus  rectirostris'],
#    'Chydorus ': ['Chydorus  gibbus',
#     'Chydorus  latus',
#     'Chydorus  ovalis',
#     'Chydorus  sphaericus'],
#    'Coronatella': ['Coronatella rectangula'],
#    'Disparalona ': ['Disparalona  rostrata'],
#    'Dunhevedia ': ['Dunhevedia  crassa'],
#    'Graptoleberis ': ['Graptoleberis  testudinaria'],
#    'Kurzia ': ['Kurzia  latissima'],
#    'Leydigia ': ['Leydigia  acanthocercoides', 'Leydigia  leydigi'],
#    'Monospilus ': ['Monospilus  dispar'],
#    'Oxyurella ': ['Oxyurella  tenuicaudis'],
#    'Paralona': ['Paralona pigra'],
#    'Phreatalona': ['Phreatalona protzi'],
#    'Pleuroxus ': ['Pleuroxus  aduncus',
#     'Pleuroxus  denticulatus',
#     'Pleuroxus  laevis',
#     'Pleuroxus  trigonellus',
#     'Pleuroxus  truncatus',
#     'Pleuroxus  uncinatus'],
#    'Pseudochydorus ': ['Pseudochydorus  globosus'],
#    'Rhynchotalona ': ['Rhynchotalona  falcata'],
#    'Tretocephala ': ['Tretocephala  ambigua']},
#   'Ctenopoda': {},
#   'Daphniidae': {'Ceriodaphnia ': ['Ceriodaphnia  dubia',
#     'Ceriodaphnia  laticaudata',
#     'Ceriodaphnia  megops',
#     'Ceriodaphnia  pulchella',
#     'Ceriodaphnia  quadrangula',
#     'Ceriodaphnia  reticulata',
#     'Ceriodaphnia  setosa'],
#    'Daphnia ': ['Daphnia  ambigua',
#     'Daphnia  atkinsoni',
#     'Daphnia  cucullata',
#     'Daphnia  curvirostris',
#     'Daphnia  galeata',
#     'Daphnia  hyalina',
#     'Daphnia  longispina',
#     'Daphnia  magna',
#     'Daphnia  obtusa',
#     'Daphnia  parvula',
#     'Daphnia  pulex',
#     'Daphnia  rosea'],
#    'Megafenestra ': ['Megafenestra  aurita'],
#    'Scapholeberis ': ['Scapholeberis  mucronata'],
#    'Simocephalus ': ['Simocephalus  exspinosus',
#     'Simocephalus  serrulatus',
#     'Simocephalus  vetulus']},
#   'Eurycercidae': {'Eurycercus ': ['Eurycercus  glacialis',
#     'Eurycercus  lamellatus']},
#   'Haplopoda': {},
#   'Holopedidae': {'Holopedium ': ['Holopedium  gibberum']},
#   'Ilyocryptidae': {'Ilyocryptus ': ['Ilyocryptus  acutifrons',
#     'Ilyocryptus  agilis',
#     'Ilyocryptus  sordidus']},
#   'Leptodoridae': {'Leptodora ': ['Leptodora  kindti']},
#   'Macrothricidae': {'Drepanothrix ': ['Drepanothrix  dentata'],
#    'Lathonura ': ['Lathonura  rectirostris'],
#    'Macrothrix ': ['Macrothrix  hirsuticornis',
#     'Macrothrix  laticornis',
#     'Macrothrix  rosea'],
#    'Streblocerus ': ['Streblocerus  serricaudatus']},
#   'Moinidae': {'Moina ': ['Moina  brachiata',
#     'Moina  macrocopa',
#     'Moina  micrura']},
#   'Onychopoda': {},
#   'Ophryoxidae': {'Ophryoxus ': ['Ophryoxus  gracilis']},
#   'Polyphemidae': {'Polyphemus ': ['Polyphemus  pediculus']},
#   'Sididae': {'Diaphanosoma ': ['Diaphanosoma  brachyurum'],
#    'Latona ': ['Latona  setifera'],
#    'Sida ': ['Sida  crystallina']}},
#  'Coelenterata': {'Clavidae': {'Cordylophora': ['Cordylophora caspia']},
#   'Hydridae': {'Hydra': ['Hydra circumcincta',
#     'Hydra graysoni',
#     'Hydra oligactis',
#     'Hydra viridissima']},
#   'Hydroida': {},
#   'Olindiidae': {'Craspedacusta': ['Craspedacusta sowerbii']},
#   'Protohydridae': {'Protohydra': ['Protohydra leuckarti']},
#   'Trachylina': {}},
#  'Coleoptera': {'Apionidae': {'Apion': []},
#   'Byrrhoidea': {},
#   'Caraboidea': {},
#   'Chrysomelidae': {'Donacia': ['Donacia aquatica',
#     'Donacia bicolora',
#     'Donacia cinerea',
#     'Donacia clavipes',
#     'Donacia crassipes',
#     'Donacia dentata',
#     'Donacia impressa',
#     'Donacia marginata',
#     'Donacia obscura',
#     'Donacia semicuprea',
#     'Donacia simplex',
#     'Donacia sparganii',
#     'Donacia thalassina',
#     'Donacia versicolorea',
#     'Donacia vulgaris'],
#    'Macroplea': ['Macroplea appendiculata', 'Macroplea mutica'],
#    'Phaedon': ['Phaedon armoraciae'],
#    'Plateumaris': ['Plateumaris braccata',
#     'Plateumaris discolor',
#     'Plateumaris sericea',
#     'Plateumaris affinis']},
#   'Chrysomeloidea': {},
#   'Colymbetinae (including Agabinae and Copelatinae)': {},
#   'Curculionidae': {'Amalorrhynchus': ['Amalorrhynchus melanarius'],
#    'Bagous': [],
#    'Bagous (Abagous)': ['Bagous (Abagous) glabrirostris',
#     'Bagous (Abagous) lutosus',
#     'Bagous (Abagous) lutulentus',
#     'Bagous (Abagous) puncticollis',
#     'Bagous (Abagous) robustus'],
#    'Bagous (Bagous)': ['Bagous (Bagous) argillaceus',
#     'Bagous (Bagous) binodulus',
#     'Bagous (Bagous) brevis',
#     'Bagous (Bagous) collignensis',
#     'Bagous (Bagous) czwalinae',
#     'Bagous (Bagous) diglyptus',
#     'Bagous (Bagous) frit',
#     'Bagous (Bagous) limosus',
#     'Bagous (Bagous) longitarsis',
#     'Bagous (Bagous) lutulosus',
#     'Bagous (Bagous) nodulosus',
#     'Bagous (Bagous) subcarinatus',
#     'Bagous (Bagous) tempestivus'],
#    'Bagous (Cyprus)': ['Bagous (Cyprus) tubulus'],
#    'Bagous (Ephimeropus)': ['Bagous (Ephimeropus) petro'],
#    'Bagous (Hydronomus)': ['Bagous (Hydronomus) alismatis'],
#    'Ceutorhynchus': [],
#    'Cionus': ['Cionus alauda', 'Cionus hortulanus', 'Cionus scrophulariae'],
#    'Cleopus': ['Cleopus pulchellus'],
#    'Datonychus': ['Datonychus melanostictus'],
#    'Drupenatus': ['Drupenatus nasturtii'],
#    'Eubrychius': ['Eubrychius velutus'],
#    'Gymnetron': ['Gymnetron beccabungae',
#     'Gymnetron veronicae',
#     'Gymnetron villosulum'],
#    'Hypera': [],
#    'Hypera (Eririnomorphus)': ['Hypera (Eririnomorphus) pollux',
#     'Hypera (Eririnomorphus) arundinis',
#     'Hypera (Eririnomorphus) rumicis'],
#    'Hypera (Hypera)': ['Hypera (Hypera) suspiciosa'],
#    'Limnobaris': ['Limnobaris dolorosa', 'Limnobaris t-album'],
#    'Lixus': [],
#    'Lixus (Lixus)': ['Lixus (Lixus) paraplecticus'],
#    'Mecinus': ['Mecinus collaris'],
#    'Mononychus': ['Mononychus punctumalbum'],
#    'Neophytobius': ['Neophytobius muricatus', 'Neophytobius quadrinodosus'],
#    'Pelenomus': ['Pelenomus canaliculatus',
#     'Pelenomus comari',
#     'Pelenomus olssoni',
#     'Pelenomus quadricorniger',
#     'Pelenomus waltoni'],
#    'Phytobius': ['Phytobius leucogaster'],
#    'Poophagus': ['Poophagus sisymbrii'],
#    'Rhinoncus': ['Rhinoncus albicinctus'],
#    'Tanysphyrus': ['Tanysphyrus lemnae'],
#    'Tapeinotus': ['Tapeinotus sellatus']},
#   'Curculionoidea': {},
#   'Dryopidae': {'Dryops': [],
#    'Dryops (Dryops)': ['Dryops (Dryops) anglicanus',
#     'Dryops (Dryops) auriculatus',
#     'Dryops (Dryops) ernesti',
#     'Dryops (Dryops) griseus',
#     'Dryops (Dryops) luridus',
#     'Dryops (Dryops) striatellus',
#     'Dryops (Dryops) similaris'],
#    'Dryops (Yrdops)': ['Dryops (Yrdops) nitidulus'],
#    'Pomatinus': ['Pomatinus substriatus']},
#   'Dytiscidae': {'Acilius': ['Acilius canaliculatus', 'Acilius sulcatus'],
#    'Agabus': [],
#    'Agabus (Acatodes)': ['Agabus (Acatodes) arcticus',
#     'Agabus (Acatodes) congener',
#     'Agabus (Acatodes) sturmii'],
#    'Agabus (Agabus)': ['Agabus (Agabus) labiatus',
#     'Agabus (Agabus) uliginosus',
#     'Agabus (Agabus) undulatus'],
#    'Agabus (Gaurodytes)': ['Agabus (Gaurodytes) affinis',
#     'Agabus (Gaurodytes) biguttatus',
#     'Agabus (Gaurodytes) bipustulatus',
#     'Agabus (Gaurodytes) brunneus',
#     'Agabus (Gaurodytes) conspersus',
#     'Agabus (Gaurodytes) didymus',
#     'Agabus (Gaurodytes) guttatus',
#     'Agabus (Gaurodytes) melanarius',
#     'Agabus (Gaurodytes) nebulosus',
#     'Agabus (Gaurodytes) paludosus',
#     'Agabus (Gaurodytes) striolatus',
#     'Agabus (Gaurodytes) unguicularis'],
#    'Bidessus': ['Bidessus minutissimus', 'Bidessus unistriatus'],
#    'Colymbetes': ['Colymbetes fuscus'],
#    'Cybister': ['Cybister lateralimarginalis'],
#    'Deronectes': ['Deronectes latus'],
#    'Dytiscus': ['Dytiscus circumcinctus',
#     'Dytiscus circumflexus',
#     'Dytiscus dimidiatus',
#     'Dytiscus lapponicus',
#     'Dytiscus marginalis',
#     'Dytiscus semisulcatus'],
#    'Graphoderus': ['Graphoderus bilineatus',
#     'Graphoderus cinereus',
#     'Graphoderus zonatus'],
#    'Graptodytes': ['Graptodytes bilineatus',
#     'Graptodytes flavipes',
#     'Graptodytes granularis',
#     'Graptodytes pictus'],
#    'Hydaticus': ['Hydaticus seminiger', 'Hydaticus transversalis'],
#    'Hydroglyphus': ['Hydroglyphus geminus'],
#    'Hydroporus': ['Hydroporus angustatus',
#     'Hydroporus necopinatus',
#     'Hydroporus discretus',
#     'Hydroporus elongatulus',
#     'Hydroporus erythrocephalus',
#     'Hydroporus ferrugineus',
#     'Hydroporus glabriusculus',
#     'Hydroporus gyllenhalii',
#     'Hydroporus incognitus',
#     'Hydroporus longicornis',
#     'Hydroporus longulus',
#     'Hydroporus marginatus',
#     'Hydroporus melanarius',
#     'Hydroporus memnonius',
#     'Hydroporus morio',
#     'Hydroporus neglectus',
#     'Hydroporus nigrita',
#     'Hydroporus obscurus',
#     'Hydroporus obsoletus',
#     'Hydroporus palustris',
#     'Hydroporus planus',
#     'Hydroporus pubescens',
#     'Hydroporus rufifrons',
#     'Hydroporus scalesianus',
#     'Hydroporus striola',
#     'Hydroporus tessellatus',
#     'Hydroporus tristis',
#     'Hydroporus umbrosus'],
#    'Hydrovatus': ['Hydrovatus clypealis', 'Hydrovatus cuspidatus'],
#    'Hygrotus': [],
#    'Hygrotus (Coelambus)': ['Hygrotus (Coelambus) confluens',
#     'Hygrotus (Coelambus) impressopunctatus',
#     'Hygrotus (Coelambus) nigrolineatus',
#     'Hygrotus (Coelambus) novemlineatus',
#     'Hygrotus (Coelambus) parallellogrammus'],
#    'Hygrotus (Hygrotus)': ['Hygrotus (Hygrotus) decoratus',
#     'Hygrotus (Hygrotus) inaequalis',
#     'Hygrotus (Hygrotus) quinquelineatus',
#     'Hygrotus (Hygrotus) versicolor'],
#    'Hyphydrus': ['Hyphydrus ovatus', 'Hyphydrus aubei'],
#    'Ilybius': ['Ilybius aenescens',
#     'Ilybius ater',
#     'Ilybius fenestratus',
#     'Ilybius fuliginosus',
#     'Ilybius guttiger',
#     'Ilybius quadriguttatus',
#     'Ilybius subaeneus',
#     'Ilybius chalconatus',
#     'Ilybius montanus',
#     'Ilybius wasastjernae'],
#    'Laccophilus': ['Laccophilus hyalinus',
#     'Laccophilus minutus',
#     'Laccophilus poecilus'],
#    'Laccornis': ['Laccornis oblongus'],
#    'Liopterus': ['Liopterus haemorrhoidalis'],
#    'Nebrioporus': [],
#    'Nebrioporus (Nebrioporus)': ['Nebrioporus (Nebrioporus) assimilis',
#     'Nebrioporus (Nebrioporus) depressus',
#     'Nebrioporus (Nebrioporus) elegans'],
#    'Nebrioporus (Zimmermannius)': ['Nebrioporus (Zimmermannius) canaliculatus'],
#    'Oreodytes': ['Oreodytes davisii',
#     'Oreodytes sanmarkii',
#     'Oreodytes septentrionalis',
#     'Oreodytes alpinus'],
#    'Platambus': ['Platambus maculatus'],
#    'Porhydrus': ['Porhydrus lineatus'],
#    'Rhantus': [],
#    'Rhantus (Nartus)': ['Rhantus (Nartus) grapii'],
#    'Rhantus (Rhantus)': ['Rhantus (Rhantus) bistriatus',
#     'Rhantus (Rhantus) exsoletus',
#     'Rhantus (Rhantus) frontalis',
#     'Rhantus (Rhantus) suturalis',
#     'Rhantus (Rhantus) suturellus'],
#    'Scarodytes': ['Scarodytes halensis'],
#    'Stictonectes': ['Stictonectes lepidus'],
#    'Stictotarsus': ['Stictotarsus duodecimpustulatus',
#     'Stictotarsus multilineatus'],
#    'Suphrodytes': ['Suphrodytes dorsalis']},
#   'Dytiscidae (including Noteridae)': {},
#   'Elmidae': {'Elmis': ['Elmis aenea'],
#    'Esolus': ['Esolus parallelepipedus'],
#    'Limnius': ['Limnius volckmari'],
#    'Macronychus': ['Macronychus quadrituberculatus'],
#    'Normandia': ['Normandia nitens'],
#    'Oulimnius': ['Oulimnius major',
#     'Oulimnius rivularis',
#     'Oulimnius troglodytes',
#     'Oulimnius tuberculatus'],
#    'Riolus': ['Riolus cupreus', 'Riolus subviolaceus'],
#    'Stenelmis': ['Stenelmis canaliculata']},
#   'Erirhinidae': {'Grypus': ['Grypus equiseti'],
#    'Notaris': ['Notaris acridulus', 'Notaris aethiops', 'Notaris scirpi'],
#    'Stenopelmus': ['Stenopelmus rufinasus'],
#    'Thryogenes': ['Thryogenes festucae', 'Thryogenes nereis'],
#    'Tournotaris': ['Tournotaris bimaculatus']},
#   'Georissidae': {'Georissus': ['Georissus crenulatus']},
#   'Gyrinidae': {'Gyrinus': ['Gyrinus aeratus',
#     'Gyrinus paykulli',
#     'Gyrinus caspius',
#     'Gyrinus distinctus',
#     'Gyrinus marinus',
#     'Gyrinus minutus',
#     'Gyrinus natator',
#     'Gyrinus opacus',
#     'Gyrinus substriatus',
#     'Gyrinus suffriani',
#     'Gyrinus urinator'],
#    'Orectochilus': ['Orectochilus villosus']},
#   'Haliplidae': {'Brychius': ['Brychius elevatus'],
#    'Haliplus': [],
#    'Haliplus (Haliplinus)': ['Haliplus (Haliplinus) apicalis',
#     'Haliplus (Haliplinus) fluviatilis',
#     'Haliplus (Haliplinus) furcatus',
#     'Haliplus (Haliplinus) heydeni',
#     'Haliplus (Haliplinus) immaculatus',
#     'Haliplus (Haliplinus) lineolatus',
#     'Haliplus (Haliplinus) ruficollis',
#     'Haliplus (Haliplinus) sibiricus'],
#    'Haliplus (Haliplus)': ['Haliplus (Haliplus) confinis',
#     'Haliplus (Haliplus) obliquus',
#     'Haliplus (Haliplus) varius'],
#    'Haliplus (Liaphlus)': ['Haliplus (Liaphlus) flavicollis',
#     'Haliplus (Liaphlus) fulvus',
#     'Haliplus (Liaphlus) laminatus',
#     'Haliplus (Liaphlus) mucronatus',
#     'Haliplus (Liaphlus) variegatus'],
#    'Haliplus (Neohaliplus)': ['Haliplus (Neohaliplus) lineatocollis'],
#    'Peltodytes': ['Peltodytes caesus']},
#   'Helophoridae': {'Helophorus': [],
#    'Helophorus (Atracthelophorus)': ['Helophorus (Atracthelophorus) arvernicus',
#     'Helophorus (Atracthelophorus) brevipalpis'],
#    'Helophorus (Cyphelophorus)': ['Helophorus (Cyphelophorus) tuberculatus'],
#    'Helophorus (Empleurus)': ['Helophorus (Empleurus) nubilus',
#     'Helophorus (Empleurus) porculus',
#     'Helophorus (Empleurus) rufipes'],
#    'Helophorus (Helophorus)': ['Helophorus (Helophorus) dorsalis',
#     'Helophorus (Helophorus) flavipes',
#     'Helophorus (Helophorus) fulgidicollis',
#     'Helophorus (Helophorus) granularis',
#     'Helophorus (Helophorus) griseus',
#     'Helophorus (Helophorus) laticollis',
#     'Helophorus (Helophorus) longitarsis',
#     'Helophorus (Helophorus) minutus',
#     'Helophorus (Helophorus) nanus',
#     'Helophorus (Helophorus) obscurus',
#     'Helophorus (Helophorus) strigifrons'],
#    'Helophorus (Megahelophorus)': ['Helophorus (Megahelophorus) aequalis',
#     'Helophorus (Megahelophorus) grandis'],
#    'Helophorus (Trichohelophorus)': ['Helophorus (Trichohelophorus) alternans']},
#   'Heteroceridae': {'Augyles': ['Augyles hispidulus', 'Augyles maritimus'],
#    'Heterocerus': ['Heterocerus flexuosus',
#     'Heterocerus fossor',
#     'Heterocerus fusculus',
#     'Heterocerus marginatus',
#     'Heterocerus obsoletus',
#     'Heterocerus fenestratus']},
#   'Hydraenidae': {'Aulacochthebius': ['Aulacochthebius exaratus'],
#    'Enicocerus': ['Enicocerus exsculptus'],
#    'Hydraena': ['Hydraena britteni',
#     'Hydraena gracilis',
#     'Hydraena flavipes',
#     'Hydraena nigrita',
#     'Hydraena palustris',
#     'Hydraena pulchella',
#     'Hydraena pygmaea',
#     'Hydraena riparia',
#     'Hydraena rufipes',
#     'Hydraena testacea'],
#    'Limnebius': ['Limnebius aluta',
#     'Limnebius crinifer',
#     'Limnebius nitidus',
#     'Limnebius papposus',
#     'Limnebius truncatellus'],
#    'Ochthebius': [],
#    'Ochthebius (Asiobates)': ['Ochthebius (Asiobates) auriculatus',
#     'Ochthebius (Asiobates) bicolon',
#     'Ochthebius (Asiobates) dilatatus'],
#    'Ochthebius (Homalochthebius)': ['Ochthebius (Homalochthebius) aeneus',
#     'Ochthebius (Homalochthebius) minimus',
#     'Ochthebius (Homalochthebius) lejolisii'],
#    'Ochthebius (Hymenodes)': ['Ochthebius (Hymenodes) nanus',
#     'Ochthebius (Hymenodes) poweri',
#     'Ochthebius (Hymenodes) punctatus'],
#    'Ochthebius (Ochthebius)': ['Ochthebius (Ochthebius) lenensis',
#     'Ochthebius (Ochthebius) marinus',
#     'Ochthebius (Ochthebius) pusillus',
#     'Ochthebius (Ochthebius) viridis']},
#   'Hydrochidae': {'Hydrochus': ['Hydrochus angustatus',
#     'Hydrochus brevis',
#     'Hydrochus crenatus',
#     'Hydrochus elongatus',
#     'Hydrochus ignicollis',
#     'Hydrochus nitidicollis',
#     'Hydrochus megaphallus']},
#   'Hydrophilidae': {'Anacaena': ['Anacaena bipustulata',
#     'Anacaena globulus',
#     'Anacaena limbata',
#     'Anacaena lutescens'],
#    'Berosus': [],
#    'Berosus (Berosus)': ['Berosus (Berosus) affinis',
#     'Berosus (Berosus) luridus',
#     'Berosus (Berosus) signaticollis'],
#    'Berosus (Enoplurus)': ['Berosus (Enoplurus) fulvus'],
#    'Cercyon': [],
#    'Cercyon (Cercyon)': ['Cercyon (Cercyon) alpinus',
#     'Cercyon (Cercyon) nigriceps',
#     'Cercyon (Cercyon) bifenestratus',
#     'Cercyon (Cercyon) convexiusculus',
#     'Cercyon (Cercyon) depressus',
#     'Cercyon (Cercyon) granarius',
#     'Cercyon (Cercyon) haemorrhoidalis',
#     'Cercyon (Cercyon) impressus',
#     'Cercyon (Cercyon) laminatus',
#     'Cercyon (Cercyon) lateralis',
#     'Cercyon (Cercyon) littoralis',
#     'Cercyon (Cercyon) marinus',
#     'Cercyon (Cercyon) melanocephalus',
#     'Cercyon (Cercyon) obsoletus',
#     'Cercyon (Cercyon) pygmaeus',
#     'Cercyon (Cercyon) quisquilius',
#     'Cercyon (Cercyon) sternalis',
#     'Cercyon (Cercyon) terminatus',
#     'Cercyon (Cercyon) tristis',
#     'Cercyon (Cercyon) unipunctatus'],
#    'Cercyon (Dicyrtocercyon)': ['Cercyon (Dicyrtocercyon) ustulatus'],
#    'Cercyon (Paracercyon)': ['Cercyon (Paracercyon) analis'],
#    'Chaetarthria': ['Chaetarthria seminulum', 'Chaetarthria simillima'],
#    'Coelostoma': ['Coelostoma orbiculare'],
#    'Cryptopleurum': ['Cryptopleurum crenatum',
#     'Cryptopleurum minutum',
#     'Cryptopleurum subtile'],
#    'Cymbiodyta': ['Cymbiodyta marginellus'],
#    'Dactylosternum': ['Dactylosternum abdominale'],
#    'Enochrus': ['Enochrus affinis',
#     'Enochrus bicolor',
#     'Enochrus coarctatus',
#     'Enochrus melanocephalus',
#     'Enochrus ochropterus',
#     'Enochrus quadripunctatus',
#     'Enochrus testaceus',
#     'Enochrus fuscipennis',
#     'Enochrus halophilus',
#     'Enochrus nigritus'],
#    'Helochares': ['Helochares lividus',
#     'Helochares obscurus',
#     'Helochares punctatus'],
#    'Hydrobius': ['Hydrobius fuscipes'],
#    'Hydrochara': ['Hydrochara caraboides'],
#    'Hydrophilus': ['Hydrophilus piceus'],
#    'Laccobius': [],
#    'Laccobius (Dimorpholaccobius)': ['Laccobius (Dimorpholaccobius) atratus',
#     'Laccobius (Dimorpholaccobius) ytenensis',
#     'Laccobius (Dimorpholaccobius) bipunctatus',
#     'Laccobius (Dimorpholaccobius) simulatrix',
#     'Laccobius (Dimorpholaccobius) sinuatus',
#     'Laccobius (Dimorpholaccobius) striatulus'],
#    'Laccobius (Laccobius)': ['Laccobius (Laccobius) colon',
#     'Laccobius (Laccobius) minutus'],
#    'Limnoxenus': ['Limnoxenus niger'],
#    'Megasternum': ['Megasternum concinnum'],
#    'Paracymus': ['Paracymus aeneus', 'Paracymus scutellaris'],
#    'Sphaeridium': ['Sphaeridium bipustulatum',
#     'Sphaeridium lunatum',
#     'Sphaeridium marginatum',
#     'Sphaeridium scarabaeoides']},
#   'Hydrophilidae (including Helophoridae, Georissidae and Hydrochidae)': {},
#   'Hydrophilidae (including Hydraenidae, Helophoridae, Georissidae and Hydrochidae)': {},
#   'Hydrophiloidea': {},
#   'Hydroporinae': {},
#   'Limnichidae': {'Limnichus': ['Limnichus pygmaeus']},
#   'Noteridae': {'Noterus': ['Noterus clavicornis', 'Noterus crassicornis']},
#   'Paelobiidae': {'Hygrobia': ['Hygrobia hermanni']},
#   'Psephenidae': {'Eubria': ['Eubria palustris']},
#   'Scirtidae': {'Cyphon': ['Cyphon coarctatus',
#     'Cyphon hilaris',
#     'Cyphon ochraceus',
#     'Cyphon padi',
#     'Cyphon palustris',
#     'Cyphon laevipennis',
#     'Cyphon pubescens',
#     'Cyphon punctipennis',
#     'Cyphon variabilis',
#     'Cyphon kongsbergensis'],
#    'Elodes': ['Elodes minuta',
#     'Elodes elongata',
#     'Elodes pseudominuta',
#     'Elodes tricuspis'],
#    'Hydrocyphon': ['Hydrocyphon deflexicollis'],
#    'Microcara': ['Microcara testacea'],
#    'Odeles': ['Odeles marginata'],
#    'Prionocyphon': ['Prionocyphon serricornis'],
#    'Scirtes': ['Scirtes hemisphaericus', 'Scirtes orbicularis']},
#   'Scirtoidea': {},
#   'Spercheidae': {'Spercheus': ['Spercheus emarginatus']},
#   'Sphaeriusidae': {'Sphaerius': ['Sphaerius acaroides']},
#   'Sphaeriusoidea': {},
#   'Staphylinoidea': {}},
#  'Collembola': {'Bourletiellidae': {'Heterosminthurus': ['Heterosminthurus insignis',
#     'Heterosminthurus novemlineatus']},
#   'Entomobryomorpha': {},
#   'Hypogastruridae': {'Hypogastrura': ['Hypogastrura viatica']},
#   'Isotomidae': {'Agrenia': ['Agrenia bidenticulata'],
#    'Ballistura': ['Ballistura borealis', 'Ballistura schoetti'],
#    'Desoria': ['Desoria infuscata'],
#    'Isotoma': ['Isotoma viridis'],
#    'Isotomurus': ['Isotomurus alticolus',
#     'Isotomurus palustris',
#     'Isotomurus antennalis'],
#    'Pachyotoma': ['Pachyotoma crassicauda'],
#    'Proisotoma': ['Proisotoma buddenbrocki']},
#   'Neanuridae': {'Anurida': ['Anurida tullbergi']},
#   'Poduridae': {'Podura': ['Podura aquatica']},
#   'Poduromorpha': {},
#   'Sminthurididae': {'Sminthurides': ['Sminthurides aquaticus',
#     'Sminthurides cruciatus',
#     'Sminthurides malmgreni',
#     'Sminthurides parvulus',
#     'Sminthurides schoetti',
#     'Sminthurides signatus'],
#    'Stenacidia': ['Stenacidia violacea']},
#   'Symphypleona': {}},
#  'Copepoda': {'Acartiidae': {'Acartia': ['Acartia bifilosa',
#     'Acartia clausi',
#     'Acartia discaudata']},
#   'Ameiridae': {'Nitokra': ['Nitokra hibernica',
#     'Nitokra lacustris',
#     'Nitokra spinipes',
#     'Nitokra typica']},
#   'Calanoida': {},
#   'Caligidae': {'Caligus': ['Caligus pageti'],
#    'Lepeophtheirus': ['Lepeophtheirus salmonis']},
#   'Canthocamptidae': {'Attheyella': [],
#    'Attheyella (Attheyella)': ['Attheyella (Attheyella) crassa'],
#    'Attheyella (Brehmiella)': ['Attheyella (Brehmiella) dentata',
#     'Attheyella (Brehmiella) trispinosa',
#     'Attheyella (Brehmiella) wulmeri'],
#    'Attheyella (Elaphoidella)': ['Attheyella (Elaphoidella) bidens',
#     'Attheyella (Elaphoidella) gracilis'],
#    'Bryocamptus': [],
#    'Bryocamptus (Arcticocamptus)': ['Bryocamptus (Arcticocamptus) cuspidatus',
#     'Bryocamptus (Arcticocamptus) rhaeticus'],
#    'Bryocamptus (Bryocamptus)': ['Bryocamptus (Bryocamptus) minutus'],
#    'Bryocamptus (Limnocamptus)': ['Bryocamptus (Limnocamptus) echinatus',
#     'Bryocamptus (Limnocamptus) praegeri'],
#    'Bryocamptus (Rheocamptus)': ['Bryocamptus (Rheocamptus) pygmaeus',
#     'Bryocamptus (Rheocamptus) typhlops',
#     'Bryocamptus (Rheocamptus) weberi',
#     'Bryocamptus (Rheocamptus) zschokkei'],
#    'Canthocamptus': ['Canthocamptus staphylinus',
#     'Canthocamptus microstaphylinus'],
#    'Epactophanes': ['Epactophanes richardi'],
#    'Maraenobiotus': ['Maraenobiotus vejdovskyi'],
#    'Mesochra': ['Mesochra aestuarii',
#     'Mesochra lilljeborgi',
#     'Mesochra rapiens'],
#    'Moraria': ['Moraria arboricola',
#     'Moraria brevipes',
#     'Moraria duthiei',
#     'Moraria mrazeki',
#     'Moraria poppei',
#     'Moraria sphagnicola',
#     'Moraria varica'],
#    'Paracamptus': ['Paracamptus schmeili']},
#   'Centropagidae': {'Centropages': ['Centropages hamatus'],
#    'Limnocalanus': ['Limnocalanus macrurus']},
#   'Cletodidae': {'Nannopus': ['Nannopus palustris']},
#   'Cyclopidae': {'Acanthocyclops': ['Acanthocyclops sensitivus',
#     'Acanthocyclops venustus',
#     'Acanthocyclops vernalis',
#     'Acanthocyclops robustus'],
#    'Cryptocyclops': ['Cryptocyclops bicolor'],
#    'Cyclops': ['Cyclops abyssorum',
#     'Cyclops furcifer',
#     'Cyclops strenuus',
#     'Cyclops vicinus',
#     'Cyclops singularis'],
#    'Diacyclops': ['Diacyclops bicuspidatus',
#     'Diacyclops bisetosus',
#     'Diacyclops crassicaudis',
#     'Diacyclops languidoides',
#     'Diacyclops languidus',
#     'Diacyclops nanus'],
#    'Ectocyclops': ['Ectocyclops phaleratus'],
#    'Eucyclops': ['Eucyclops macruroides',
#     'Eucyclops macrurus',
#     'Eucyclops serrulatus',
#     'Eucyclops speratus'],
#    'Graeteriella': ['Graeteriella unisetigera'],
#    'Halicyclops': ['Halicyclops magniceps', 'Halicyclops neglectus'],
#    'Macrocyclops': ['Macrocyclops albidus',
#     'Macrocyclops distinctus',
#     'Macrocyclops fuscus'],
#    'Megacyclops': ['Megacyclops gigas',
#     'Megacyclops latipes',
#     'Megacyclops viridis'],
#    'Mesocyclops': ['Mesocyclops leuckarti'],
#    'Metacyclops': ['Metacyclops gracilis', 'Metacyclops minutus'],
#    'Microcyclops': ['Microcyclops rubellus', 'Microcyclops varicans'],
#    'Paracyclops': ['Paracyclops affinis',
#     'Paracyclops fimbriatus',
#     'Paracyclops poppei',
#     'Paracyclops chiltoni'],
#    'Speocyclops': ['Speocyclops demetiensis'],
#    'Thermocyclops': ['Thermocyclops crassus', 'Thermocyclops dybowskii'],
#    'Tropocyclops': ['Tropocyclops prasinus']},
#   'Cyclopinidae': {'Cyclopina': ['Cyclopina norvegica', 'Cyclopina esilis'],
#    'Muceddina': ['Muceddina multispinosa']},
#   'Cyclopoida': {},
#   "D'arcythompsoniidae": {'Leptocaris': ['Leptocaris brevicornis']},
#   'Diaptomidae': {'Arctodiaptomus': [],
#    'Arctodiaptomus (Arctodiaptomus)': ['Arctodiaptomus (Arctodiaptomus) laticeps',
#     'Arctodiaptomus (Arctodiaptomus) wierzejskii'],
#    'Arctodiaptomus (Rhabdodiaptomus)': ['Arctodiaptomus (Rhabdodiaptomus) alpinus'],
#    'Diaptomus': ['Diaptomus castor', 'Diaptomus cyaneus'],
#    'Eudiaptomus': ['Eudiaptomus gracilis', 'Eudiaptomus vulgaris'],
#    'Mixodiaptomus': ['Mixodiaptomus laciniatus']},
#   'Dichelesthiidae': {'Dichelesthium': ['Dichelesthium oblongum']},
#   'Ergasilidae': {'Ergasilus': ['Ergasilus briani',
#     'Ergasilus gibbus',
#     'Ergasilus sieboldi',
#     'Ergasilus lizae'],
#    'Neoergasilus': ['Neoergasilus japonicus'],
#    'Paraergasilus': ['Paraergasilus longidigitus'],
#    'Thersitina': ['Thersitina gasterostei']},
#   'Harpacticoida': {},
#   'Laophontidae': {'Onychocamptus': ['Onychocamptus mohammed']},
#   'Lernaeidae': {'Lernaea': ['Lernaea cyprinacea']},
#   'Lernaeopodidae': {'Achtheres': ['Achtheres percarum'],
#    'Clavellisa': ['Clavellisa emarginata'],
#    'Salmincola': ['Salmincola edwardsii',
#     'Salmincola gordoni',
#     'Salmincola salmoneus',
#     'Salmincola thymalli'],
#    'Tracheliastes': ['Tracheliastes polycolpus', 'Tracheliastes maculatus']},
#   'Parastenocarididae': {'Parastenocaris': ['Parastenocaris phyllura',
#     'Parastenocaris vicesima']},
#   'Phyllognathopodidae': {'Phyllognathopus': ['Phyllognathopus viguieri']},
#   'Poecilostomatoida': {},
#   'Siphonostomatoida': {},
#   'Tachidiidae': {'Microarthridion': ['Microarthridion littorale'],
#    'Tachidius': ['Tachidius discipes', 'Tachidius incisipes']},
#   'Temoridae': {'Eurytemora': ['Eurytemora affinis',
#     'Eurytemora americana',
#     'Eurytemora velox']}},
#  'Decapoda': {'Astacidae': {'Astacus': ['Astacus astacus',
#     'Astacus leptodactylus'],
#    'Austropotamobius': ['Austropotamobius pallipes'],
#    'Pacifastacus': ['Pacifastacus leniusculus']},
#   'Astacura': {},
#   'Brachyura': {},
#   'Cambaridae': {'Orconectes': ['Orconectes limosus'],
#    'Procambarus': ['Procambarus clarkii']},
#   'Crangonidae': {'Crangon': ['Crangon crangon']},
#   'Grapsidae': {'Eriocheir': ['Eriocheir sinensis']},
#   'Natantia': {},
#   'Palaemonidae': {'Palaemon': ['Palaemon longirostris'],
#    'Palaemonetes': ['Palaemonetes varians']}},
#  'Diptera': {'Anthomyiidae': {},
#   'Athericidae': {'Atherix': ['Atherix ibis'],
#    'Atrichops': ['Atrichops crassipes'],
#    'Ibisia': ['Ibisia marginata']},
#   'Bibionidae': {},
#   'Bibionoidea': {},
#   'Buchonomyiinae': {'Buchonomyia': ['Buchonomyia thienemanni']},
#   'Ceratopogonidae': {'Allohelea': ['Allohelea tessellata'],
#    'Alluaudomyia': ['Alluaudomyia riparia'],
#    'Atrichopogon': [],
#    'Atrichopogon (Atrichopogon)': ['Atrichopogon (Atrichopogon) aethiops',
#     'Atrichopogon (Atrichopogon) brunnipes',
#     'Atrichopogon (Atrichopogon) fuscus',
#     'Atrichopogon (Atrichopogon) minutus',
#     'Atrichopogon (Atrichopogon) pavidus'],
#    'Atrichopogon (Lophomyidium)': ['Atrichopogon (Lophomyidium) rostratus'],
#    'Atrichopogon (Meloehelea)': ['Atrichopogon (Meloehelea) winnertzi',
#     'Atrichopogon (Meloehelea) oedemerarum',
#     'Atrichopogon (Meloehelea) lucorum'],
#    'Atrichopogon (Psammopogon)': ['Atrichopogon (Psammopogon) muelleri'],
#    'Atrichopogon (Psilokempia)': ['Atrichopogon (Psilokempia) appendiculatus',
#     'Atrichopogon (Psilokempia) forcipatus'],
#    'Bezzia': [],
#    'Bezzia (Bezzia)': ['Bezzia (Bezzia) coracina',
#     'Bezzia (Bezzia) decincta',
#     'Bezzia (Bezzia) flavicornis',
#     'Bezzia (Bezzia) nigritula',
#     'Bezzia (Bezzia) nobilis',
#     'Bezzia (Bezzia) ornata',
#     'Bezzia (Bezzia) pygmaea',
#     'Bezzia (Bezzia) winnertziana'],
#    'Bezzia (Homobezzia)': ['Bezzia (Homobezzia) annulipes',
#     'Bezzia (Homobezzia) bicolor',
#     'Bezzia (Homobezzia) circumdata',
#     'Bezzia (Homobezzia) fascispinosa',
#     'Bezzia (Homobezzia) leucogaster',
#     'Bezzia (Homobezzia) multiannulata',
#     'Bezzia (Homobezzia) taeniata'],
#    'Bezzia (Pygobezzia)': ['Bezzia (Pygobezzia) calceata'],
#    'Brachypogon': [],
#    'Brachypogon (Isohelea)': ['Brachypogon (Isohelea) nitidula',
#     'Brachypogon (Isohelea) perpusilla',
#     'Brachypogon (Isohelea) sociabilis'],
#    'Ceratopogon': ['Ceratopogon communis',
#     'Ceratopogon grandiforceps',
#     'Ceratopogon lacteipennis',
#     'Ceratopogon niveipennis',
#     'Ceratopogon denticulatus'],
#    'Clinohelea': ['Clinohelea unimaculata'],
#    'Culicoides': [],
#    'Culicoides (Avaritia)': ['Culicoides (Avaritia) chiopterus',
#     'Culicoides (Avaritia) dewulfi',
#     'Culicoides (Avaritia) obsoletus',
#     'Culicoides (Avaritia) scoticus'],
#    'Culicoides (Beltranmyia)': ['Culicoides (Beltranmyia) circumscriptus',
#     'Culicoides (Beltranmyia) manchuriensis',
#     'Culicoides (Beltranmyia) salinarius'],
#    'Culicoides (Culicoides)': ['Culicoides (Culicoides) delta',
#     'Culicoides (Culicoides) fagineus',
#     'Culicoides (Culicoides) grisescens',
#     'Culicoides (Culicoides) newsteadi',
#     'Culicoides (Culicoides) impunctatus',
#     'Culicoides (Culicoides) pulicaris',
#     'Culicoides (Culicoides) punctatus'],
#    'Culicoides (Monoculicoides)': ['Culicoides (Monoculicoides) nubeculosus',
#     'Culicoides (Monoculicoides) parroti',
#     'Culicoides (Monoculicoides) puncticollis',
#     'Culicoides (Monoculicoides) riethi',
#     'Culicoides (Monoculicoides) stigma'],
#    'Culicoides (Oecacta)': ['Culicoides (Oecacta) albicans',
#     'Culicoides (Oecacta) brunnicans',
#     'Culicoides (Oecacta) cataneii',
#     'Culicoides (Oecacta) duddingstoni',
#     'Culicoides (Oecacta) furcillatus',
#     'Culicoides (Oecacta) heliophilus',
#     'Culicoides (Oecacta) kibunensis',
#     'Culicoides (Oecacta) maritimus',
#     'Culicoides (Oecacta) minutissimus',
#     'Culicoides (Oecacta) alazanicus',
#     'Culicoides (Oecacta) festivipennis',
#     'Culicoides (Oecacta) poperinghensis',
#     'Culicoides (Oecacta) griseidorsum',
#     'Culicoides (Oecacta) simulator',
#     'Culicoides (Oecacta) clintoni',
#     'Culicoides (Oecacta) vexans',
#     'Culicoides (Oecacta) cameroni',
#     'Culicoides (Oecacta) reconditus',
#     'Culicoides (Oecacta) segnis',
#     'Culicoides (Oecacta) tbilisicus',
#     'Culicoides (Oecacta) clastrieri'],
#    'Culicoides (Silvaticulicoides)': ['Culicoides (Silvaticulicoides) achrayi',
#     'Culicoides (Silvaticulicoides) fascipennis',
#     'Culicoides (Silvaticulicoides) pallidicornis',
#     'Culicoides (Silvaticulicoides) picturatus',
#     'Culicoides (Silvaticulicoides) subfasciipennis'],
#    'Dasyhelea': [],
#    'Dasyhelea (Dasyhelea)': ['Dasyhelea (Dasyhelea) bensoni',
#     'Dasyhelea (Dasyhelea) dufouri',
#     'Dasyhelea (Dasyhelea) flavifrons',
#     'Dasyhelea (Dasyhelea) saxicola'],
#    'Dasyhelea (Dicryptoscena)': ['Dasyhelea (Dicryptoscena) modesta',
#     'Dasyhelea (Dicryptoscena) notata'],
#    'Dasyhelea (Prokempia)': ['Dasyhelea (Prokempia) flaviventris',
#     'Dasyhelea (Prokempia) biunguis'],
#    'Dasyhelea (Pseudoculicoides)': ['Dasyhelea (Pseudoculicoides) corinneae',
#     'Dasyhelea (Pseudoculicoides) flavoscutellata'],
#    'Dasyhelea (Sebessia)': ['Dasyhelea (Sebessia) acuminata',
#     'Dasyhelea (Sebessia) holosericea'],
#    'Forcipomyia': [],
#    'Forcipomyia (Caloforcipomyia)': ['Forcipomyia (Caloforcipomyia) glauca'],
#    'Forcipomyia (Euprojoannisia)': ['Forcipomyia (Euprojoannisia) alacris',
#     'Forcipomyia (Euprojoannisia) palustris',
#     'Forcipomyia (Euprojoannisia) phlebotomoides',
#     'Forcipomyia (Euprojoannisia) titillans'],
#    'Forcipomyia (Forcipomyia)': ['Forcipomyia (Forcipomyia) bipunctata',
#     'Forcipomyia (Forcipomyia) brevipennis',
#     'Forcipomyia (Forcipomyia) ciliata',
#     'Forcipomyia (Forcipomyia) kaltenbachii',
#     'Forcipomyia (Forcipomyia) myrmecophila',
#     'Forcipomyia (Forcipomyia) nigra',
#     'Forcipomyia (Forcipomyia) costata',
#     'Forcipomyia (Forcipomyia) pulchrithorax',
#     'Forcipomyia (Forcipomyia) radicicola',
#     'Forcipomyia (Forcipomyia) sphagnophila',
#     'Forcipomyia (Forcipomyia) tenuisquama',
#     'Forcipomyia (Forcipomyia) crassipes'],
#    'Forcipomyia (Microhelea)': ['Forcipomyia (Microhelea) fuliginosa'],
#    'Forcipomyia (Panhelea)': ['Forcipomyia (Panhelea) brevicubitus'],
#    'Forcipomyia (Pterobosca)': ['Forcipomyia (Pterobosca) paludis'],
#    'Forcipomyia (Synthyridomyia)': ['Forcipomyia (Synthyridomyia) murina'],
#    'Forcipomyia (Thyridomyia)': ['Forcipomyia (Thyridomyia) frutetorum',
#     'Forcipomyia (Thyridomyia) monilicornis',
#     'Forcipomyia (Thyridomyia) rugosa'],
#    'Forcipomyia (Trichohelea)': ['Forcipomyia (Trichohelea) eques',
#     'Forcipomyia (Trichohelea) tonnoiri'],
#    'Kolenohelea': ['Kolenohelea calcarata'],
#    'Mallochohelea': ['Mallochohelea inermis',
#     'Mallochohelea munda',
#     'Mallochohelea nitida',
#     'Mallochohelea setigera'],
#    'Neurohelea': ['Neurohelea luteitarsis'],
#    'Palpomyia': ['Palpomyia armipes',
#     'Palpomyia brevicornis',
#     'Palpomyia distincta',
#     'Palpomyia flavipes',
#     'Palpomyia grossipes',
#     'Palpomyia lineata',
#     'Palpomyia luteifemorata',
#     'Palpomyia brachialis',
#     'Palpomyia nigripes',
#     'Palpomyia praeusta',
#     'Palpomyia quadrispinosa',
#     'Palpomyia semifumosa',
#     'Palpomyia serripes',
#     'Palpomyia spinipes',
#     'Palpomyia tibialis',
#     'Palpomyia pubescens'],
#    'Phaenobezzia': ['Phaenobezzia rubiginosa'],
#    'Probezzia': ['Probezzia seminigra', 'Probezzia concinna'],
#    'Schizohelea': ['Schizohelea leucopeza'],
#    'Serromyia': ['Serromyia atra',
#     'Serromyia femorata',
#     'Serromyia morio',
#     'Serromyia ledicola',
#     'Serromyia rufitarsis',
#     'Serromyia subinermis'],
#    'Sphaeromias': ['Sphaeromias miricornis',
#     'Sphaeromias fasciatus',
#     'Sphaeromias pictus'],
#    'Stilobezzia': [],
#    'Stilobezzia (Acanthohelea)': ['Stilobezzia (Acanthohelea) gracilis',
#     'Stilobezzia (Acanthohelea) lutacea',
#     'Stilobezzia (Acanthohelea) ochracea'],
#    'Stilobezzia (Stilobezzia)': ['Stilobezzia (Stilobezzia) flavirostris']},
#   'Chaoboridae': {'Chaoborus': [],
#    'Chaoborus (Chaoborus)': ['Chaoborus (Chaoborus) crystallinus',
#     'Chaoborus (Chaoborus) flavicans',
#     'Chaoborus (Chaoborus) obscuripes'],
#    'Chaoborus (Peusomyia)': ['Chaoborus (Peusomyia) pallidus'],
#    'Mochlonyx': ['Mochlonyx velutinus', 'Mochlonyx fuliginosus']},
#   'Chironomidae': {},
#   'Chironominae (Chironomini)': {'Chironomus': [],
#    'Chironomus (Camptochironomus)': ['Chironomus (Camptochironomus) pallidivittatus',
#     'Chironomus (Camptochironomus) tentans'],
#    'Chironomus (Chaetolabis)': ['Chironomus (Chaetolabis) macani'],
#    'Chironomus (Chironomus)': ['Chironomus (Chironomus) annularius',
#     'Chironomus (Chironomus) anthracinus',
#     'Chironomus (Chironomus) aprilinus',
#     'Chironomus (Chironomus) cingulatus',
#     'Chironomus (Chironomus) dorsalis',
#     'Chironomus (Chironomus) inermifrons',
#     'Chironomus (Chironomus) longistylus',
#     'Chironomus (Chironomus) lugubris',
#     'Chironomus (Chironomus) luridus',
#     'Chironomus (Chironomus) nuditarsis',
#     'Chironomus (Chironomus) obtusidens',
#     'Chironomus (Chironomus) pilicornis',
#     'Chironomus (Chironomus) plumosus',
#     'Chironomus (Chironomus) prasinus',
#     'Chironomus (Chironomus) pseudothummi',
#     'Chironomus (Chironomus) riparius',
#     'Chironomus (Chironomus) salinarius',
#     'Chironomus (Chironomus) striatus',
#     'Chironomus (Chironomus) venustus',
#     'Chironomus (Chironomus) lacunaris',
#     'Chironomus (Chironomus) piger',
#     'Chironomus (Chironomus) strenzkei',
#     'Chironomus (Chironomus) nudiventris',
#     'Chironomus (Chironomus) crassimanus',
#     'Chironomus (Chironomus) entis',
#     'Chironomus (Chironomus) holomelas'],
#    'Chironomus (Lobochironomus)': ['Chironomus (Lobochironomus) dissidens',
#     'Chironomus (Lobochironomus) dorsalis',
#     'Chironomus (Lobochironomus) carbonarius'],
#    'Cladopelma': ['Cladopelma edwardsi',
#     'Cladopelma krusemani',
#     'Cladopelma goetghebueri',
#     'Cladopelma virescens',
#     'Cladopelma viridulum',
#     'Cladopelma bicarinatum'],
#    'Cryptochironomus': ['Cryptochironomus albofasciatus',
#     'Cryptochironomus denticulatus',
#     'Cryptochironomus obreptans',
#     'Cryptochironomus psittacinus',
#     'Cryptochironomus redekei',
#     'Cryptochironomus rostratus',
#     'Cryptochironomus supplicans',
#     'Cryptochironomus defectus'],
#    'Cryptotendipes': ['Cryptotendipes holsatus',
#     'Cryptotendipes nigronitens',
#     'Cryptotendipes pflugfelderi',
#     'Cryptotendipes pseudotener',
#     'Cryptotendipes usmaensis'],
#    'Demeijerea': ['Demeijerea rufipes'],
#    'Demicryptochironomus': [],
#    'Demicryptochironomus (Demicryptochironomus)': ['Demicryptochironomus (Demicryptochironomus) vulneratus'],
#    'Demicryptochironomus (Irmakia)': ['Demicryptochironomus (Irmakia) neglectus'],
#    'Dicrotendipes': ['Dicrotendipes pallidicornis',
#     'Dicrotendipes lobiger',
#     'Dicrotendipes nervosus',
#     'Dicrotendipes notatus',
#     'Dicrotendipes pulsus',
#     'Dicrotendipes tritomus'],
#    'Einfeldia': ['Einfeldia pagana', 'Einfeldia palaearctica'],
#    'Endochironomus': ['Endochironomus albipennis', 'Endochironomus tendens'],
#    'Fleuria': ['Fleuria lacustris'],
#    'Glyptotendipes': [],
#    'Glyptotendipes (Caulochironomus)': ['Glyptotendipes (Caulochironomus) foliicola',
#     'Glyptotendipes (Caulochironomus) imbecilis',
#     'Glyptotendipes (Caulochironomus) scirpi',
#     'Glyptotendipes (Caulochironomus) viridis'],
#    'Glyptotendipes (Glyptotendipes)': ['Glyptotendipes (Glyptotendipes) barbipes',
#     'Glyptotendipes (Glyptotendipes) cauliginellus',
#     'Glyptotendipes (Glyptotendipes) pallens',
#     'Glyptotendipes (Glyptotendipes) paripes',
#     'Glyptotendipes (Glyptotendipes) glaucus',
#     'Glyptotendipes (Glyptotendipes) salinus'],
#    'Glyptotendipes (Heynotendipes)': ['Glyptotendipes (Heynotendipes) signatus'],
#    'Graceus': ['Graceus ambiguus'],
#    'Harnischia': ['Harnischia curtilamellata', 'Harnischia fuscimana'],
#    'Kiefferulus': ['Kiefferulus tendipediformis'],
#    'Lauterborniella': ['Lauterborniella agrayloides'],
#    'Microchironomus': ['Microchironomus deribae', 'Microchironomus tener'],
#    'Microtendipes': ['Microtendipes britteni',
#     'Microtendipes chloris',
#     'Microtendipes confinis',
#     'Microtendipes diffinis',
#     'Microtendipes nitidus',
#     'Microtendipes pedellus',
#     'Microtendipes rydalensis',
#     'Microtendipes tarsalis'],
#    'Nilothauma': ['Nilothauma brayi'],
#    'Omisus': ['Omisus caledonicus'],
#    'Pagastiella': ['Pagastiella orophila'],
#    'Parachironomus': ['Parachironomus arcuatus',
#     'Parachironomus biannulatus',
#     'Parachironomus digitalis',
#     'Parachironomus frequens',
#     'Parachironomus mauricii',
#     'Parachironomus monochromus',
#     'Parachironomus parilis',
#     'Parachironomus tenuicaudatus',
#     'Parachironomus varus',
#     'Parachironomus vitiosus',
#     'Parachironomus subalpinus',
#     'Parachironomus swammerdami'],
#    'Paracladopelma': ['Paracladopelma camptolabis',
#     'Paracladopelma laminatum',
#     'Paracladopelma nigritulum'],
#    'Paralauterborniella': ['Paralauterborniella nigrohalteralis'],
#    'Paratendipes': ['Paratendipes albimanus',
#     'Paratendipes nudisquama',
#     'Paratendipes plebeius'],
#    'Phaenopsectra': ['Phaenopsectra flavipes', 'Phaenopsectra punctipes'],
#    'Polypedilum': [],
#    'Polypedilum (Pentapedilum)': ['Polypedilum (Pentapedilum) nubens',
#     'Polypedilum (Pentapedilum) sordens',
#     'Polypedilum (Pentapedilum) tritum',
#     'Polypedilum (Pentapedilum) uncinatum'],
#    'Polypedilum (Polypedilum)': ['Polypedilum (Polypedilum) acutum',
#     'Polypedilum (Polypedilum) albicorne',
#     'Polypedilum (Polypedilum) arundineti',
#     'Polypedilum (Polypedilum) laetum',
#     'Polypedilum (Polypedilum) nubeculosum',
#     'Polypedilum (Polypedilum) pedestre'],
#    'Polypedilum (Tripodura)': ['Polypedilum (Tripodura) apfelbecki',
#     'Polypedilum (Tripodura) bicrenatum',
#     'Polypedilum (Tripodura) pullum',
#     'Polypedilum (Tripodura) quadriguttatum',
#     'Polypedilum (Tripodura) scalaenum',
#     'Polypedilum (Tripodura) tetracrenatum',
#     'Polypedilum (Tripodura) aegyptium'],
#    'Polypedilum (Uresipedilum)': ['Polypedilum (Uresipedilum) convictum',
#     'Polypedilum (Uresipedilum) cultellatum'],
#    'Saetheria': ['Saetheria reissi'],
#    'Sergentia': ['Sergentia coracina',
#     'Sergentia psiloptera',
#     'Sergentia baueri',
#     'Sergentia prima'],
#    'Stenochironomus': ['Stenochironomus hibernicus'],
#    'Stenochironomus (Petalopholeus)': ['Stenochironomus (Petalopholeus) fascipennis'],
#    'Stenochironomus (Stenochironomus)': ['Stenochironomus (Stenochironomus) gibbus'],
#    'Stictochironomus': ['Stictochironomus maculipennis',
#     'Stictochironomus pictulus',
#     'Stictochironomus rosenschoeldi',
#     'Stictochironomus sticticus'],
#    'Synendotendipes': ['Synendotendipes dispar',
#     'Synendotendipes impar',
#     'Synendotendipes lepidus'],
#    'Tribelos': ['Tribelos intextus'],
#    'Xenochironomus': ['Xenochironomus xenolabis'],
#    'Zavreliella': ['Zavreliella marmorata']},
#   'Chironominae (Pseudochironomini)': {'Pseudochironomus': ['Pseudochironomus prasinatus']},
#   'Chironominae (Tanytarsini)': {'Cladotanytarsus': ['Cladotanytarsus atridorsum',
#     'Cladotanytarsus difficilis',
#     'Cladotanytarsus dispersopilosus',
#     'Cladotanytarsus iucundus',
#     'Cladotanytarsus mancus',
#     'Cladotanytarsus nigrovittatus',
#     'Cladotanytarsus vanderwulpi',
#     'Cladotanytarsus lepidocalcar',
#     'Cladotanytarsus molestus'],
#    'Corynocera': ['Corynocera ambigua'],
#    'Micropsectra': ['Micropsectra apposita',
#     'Micropsectra aristata',
#     'Micropsectra atrofasciata',
#     'Micropsectra attenuata',
#     'Micropsectra bidentata',
#     'Micropsectra fusca',
#     'Micropsectra groenlandica',
#     'Micropsectra junci',
#     'Micropsectra lindebergi',
#     'Micropsectra lindrothi',
#     'Micropsectra notescens',
#     'Micropsectra recurvata',
#     'Micropsectra subnitens',
#     'Micropsectra contracta',
#     'Micropsectra radialis'],
#    'Neozavrelia': ['Neozavrelia fuldensis',
#     'Neozavrelia longappendiculata',
#     'Neozavrelia luteola'],
#    'Parapsectra': ['Parapsectra chionophila',
#     'Parapsectra nana',
#     'Parapsectra uliginosa'],
#    'Paratanytarsus': ['Paratanytarsus austriacus',
#     'Paratanytarsus bituberculatus',
#     'Paratanytarsus dissimilis',
#     'Paratanytarsus inopertus',
#     'Paratanytarsus intricatus',
#     'Paratanytarsus laccophilus',
#     'Paratanytarsus laetipes',
#     'Paratanytarsus lauterborni',
#     'Paratanytarsus natvigi',
#     'Paratanytarsus penicillatus',
#     'Paratanytarsus tenellulus',
#     'Paratanytarsus tenuis',
#     'Paratanytarsus dimorphis',
#     'Paratanytarsus grimmii'],
#    'Rheotanytarsus': ['Rheotanytarsus curtistylus',
#     'Rheotanytarsus pellucidus',
#     'Rheotanytarsus muscicola',
#     'Rheotanytarsus pentapoda',
#     'Rheotanytarsus photophilus',
#     'Rheotanytarsus reissi',
#     'Rheotanytarsus rhenanus',
#     'Rheotanytarsus nigricauda',
#     'Rheotanytarsus ringei',
#     'Rheotanytarsus rioensis'],
#    'Stempellina': ['Stempellina bausei', 'Stempellina almi'],
#    'Stempellinella': ['Stempellinella brevis',
#     'Stempellinella cuneipennis',
#     'Stempellinella flavidula',
#     'Stempellinella edwardsi'],
#    'Tanytarsus': ['Tanytarsus bathophilus',
#     'Tanytarsus brundini',
#     'Tanytarsus buchonius',
#     'Tanytarsus chinyensis',
#     'Tanytarsus curticornis',
#     'Tanytarsus debilis',
#     'Tanytarsus ejuncidus',
#     'Tanytarsus eminulus',
#     'Tanytarsus excavatus',
#     'Tanytarsus volgensis',
#     'Tanytarsus glabrescens',
#     'Tanytarsus gracilentus',
#     'Tanytarsus gregarius',
#     'Tanytarsus heusdensis',
#     'Tanytarsus inaequalis',
#     'Tanytarsus lactescens',
#     'Tanytarsus lestagei',
#     'Tanytarsus lugens',
#     'Tanytarsus medius',
#     'Tanytarsus mendax',
#     'Tanytarsus miriforceps',
#     'Tanytarsus nemorosus',
#     'Tanytarsus niger',
#     'Tanytarsus occultus',
#     'Tanytarsus palettaris',
#     'Tanytarsus pallidicornis',
#     'Tanytarsus palmeni',
#     'Tanytarsus quadridentatus',
#     'Tanytarsus recurvatus',
#     'Tanytarsus signatus',
#     'Tanytarsus striatulus',
#     'Tanytarsus sylvaticus',
#     'Tanytarsus usmaensis',
#     'Tanytarsus verralli',
#     'Tanytarsus aculeatus',
#     'Tanytarsus dispar',
#     'Tanytarsus gibbosiceps',
# ...
#    'Eothinia': ['Eothinia elongata'],
#    'Itura': ['Itura aurita', 'Itura viridis'],
#    'Metadiaschiza': ['Metadiaschiza trigona'],
#    'Monommata': ['Monommata actices',
#     'Monommata aequalis',
#     'Monommata astia',
#     'Monommata grandis',
#     'Monommata longiseta'],
#    'Notommata': ['Notommata allantois',
#     'Notommata aurita',
#     'Notommata brachyota',
#     'Notommata cerberus',
#     'Notommata collaris',
#     'Notommata contorta',
#     'Notommata copeus',
#     'Notommata cyrtopus',
#     'Notommata groenlandica',
#     'Notommata pachyura',
#     'Notommata pseudocerberus',
#     'Notommata saccigera',
#     'Notommata silpha',
#     'Notommata tripus'],
#    'Pleurotrocha': ['Pleurotrocha constricta', 'Pleurotrocha petromycon'],
#    'Resticula': ['Resticula melandocus'],
#    'Scaridium': ['Scaridium longicaudum'],
#    'Taphrocampa': ['Taphrocampa annulosa',
#     'Taphrocampa clavigera',
#     'Taphrocampa selenura'],
#    'Tetrasiphon': ['Tetrasiphon hydrocora']},
#   'Philodinavidae': {'Henoceros': ['Henoceros falcatus'],
#    'Philodinavus': ['Philodinavus paradoxus']},
#   'Philodinidae': {'Ceratotrocha': ['Ceratotrocha cornigera'],
#    'Dissotrocha': ['Dissotrocha aculeata',
#     'Dissotrocha macrostyla',
#     'Dissotrocha spinosa'],
#    'Embata': ['Embata commensalis',
#     'Embata hamata',
#     'Embata laticeps',
#     'Embata laticornis',
#     'Embata parasitica'],
#    'Macrotrachela': ['Macrotrachela aculeata',
#     'Macrotrachela angusta',
#     'Macrotrachela asperula',
#     'Macrotrachela bilfingeri',
#     'Macrotrachela bullata',
#     'Macrotrachela concinna',
#     'Macrotrachela crucicornis',
#     'Macrotrachela decora',
#     'Macrotrachela ehrenbergi',
#     'Macrotrachela fungicola',
#     'Macrotrachela habita',
#     'Macrotrachela multispinosa',
#     'Macrotrachela muricata',
#     'Macrotrachela musculosa',
#     'Macrotrachela nana',
#     'Macrotrachela natans',
#     'Macrotrachela ornata',
#     'Macrotrachela papillosa',
#     'Macrotrachela plicata',
#     'Macrotrachela quadricornifera',
#     'Macrotrachela vesicularis'],
#    'Mniobia': ['Mniobia armata',
#     'Mniobia circinata',
#     'Mniobia incrassata',
#     'Mniobia magna',
#     'Mniobia russeola',
#     'Mniobia scarlatina',
#     'Mniobia symbiotica',
#     'Mniobia tetraodon'],
#    'Philodina': ['Philodina acuticornis',
#     'Philodina brevipes',
#     'Philodina citrina',
#     'Philodina convergens',
#     'Philodina erythrophthalma',
#     'Philodina flaviceps',
#     'Philodina megalotrocha',
#     'Philodina nemoralis',
#     'Philodina plena',
#     'Philodina roseola',
#     'Philodina rugosa',
#     'Philodina vorax'],
#    'Pleuretra': ['Pleuretra alpium', 'Pleuretra brycei', 'Pleuretra humerosa'],
#    'Rotaria': ['Rotaria citrina',
#     'Rotaria curtipes',
#     'Rotaria elongata',
#     'Rotaria haptica',
#     'Rotaria macroceros',
#     'Rotaria macrura',
#     'Rotaria magna-calcarata',
#     'Rotaria mento',
#     'Rotaria murrayi',
#     'Rotaria neptunia',
#     'Rotaria neptunoida',
#     'Rotaria quadrioculata',
#     'Rotaria rotatoria',
#     'Rotaria socialis',
#     'Rotaria sordida',
#     'Rotaria spicata',
#     'Rotaria tardigrada',
#     'Rotaria trisecata']},
#   'Ploimida': {},
#   'Proalidae': {'Bryceella': ['Bryceella stylata', 'Bryceella tenella'],
#    'Proales': ['Proales daphnicola',
#     'Proales decipiens',
#     'Proales doliaris',
#     'Proales fallaciosa',
#     'Proales giganthea',
#     'Proales globulifera',
#     'Proales micropus',
#     'Proales minima',
#     'Proales parasita',
#     'Proales reinhardti',
#     'Proales similis',
#     'Proales sordida',
#     'Proales theodora',
#     'Proales wernecki'],
#    'Proalinopsis': ['Proalinopsis caudatus',
#     'Proalinopsis squamipes',
#     'Proalinopsis staurus']},
#   'Synchaetidae': {'Ploesoma': [],
#    'Ploesoma (Bipalpus)': ['Ploesoma (Bipalpus) hudsoni'],
#    'Ploesoma (Ploesoma)': ['Ploesoma (Ploesoma) lenticulare',
#     'Ploesoma (Ploesoma) triacanthum',
#     'Ploesoma (Ploesoma) truncatum'],
#    'Polyarthra': ['Polyarthra dolichoptera',
#     'Polyarthra euryptera',
#     'Polyarthra major',
#     'Polyarthra minor',
#     'Polyarthra remata',
#     'Polyarthra vulgaris'],
#    'Synchaeta': ['Synchaeta baltica',
#     'Synchaeta bicornis',
#     'Synchaeta calva',
#     'Synchaeta cecilia',
#     'Synchaeta grandis',
#     'Synchaeta grimpei',
#     'Synchaeta gyrina',
#     'Synchaeta litoralis',
#     'Synchaeta longipes',
#     'Synchaeta oblonga',
#     'Synchaeta pectinata',
#     'Synchaeta stylata',
#     'Synchaeta tavina',
#     'Synchaeta tremula',
#     'Synchaeta triophthalma',
#     'Synchaeta vorax']},
#   'Testudinellidae': {'Pompholyx': ['Pompholyx complanata',
#     'Pompholyx sulcata'],
#    'Testudinella': ['Testudinella caeca',
#     'Testudinella clypeata',
#     'Testudinella elliptica',
#     'Testudinella incisa',
#     'Testudinella mucronata',
#     'Testudinella parva',
#     'Testudinella patina',
#     'Testudinella reflexa',
#     'Testudinella truncata']},
#   'Trichocercidae': {'Ascomorphella': ['Ascomorphella volvocicola'],
#    'Elosa': ['Elosa woralli'],
#    'Trichocerca': [],
#    'Trichocerca (Diurella)': ['Trichocerca (Diurella) bidens',
#     'Trichocerca (Diurella) birostris',
#     'Trichocerca (Diurella) brachyura',
#     'Trichocerca (Diurella) cavia',
#     'Trichocerca (Diurella) collaris',
#     'Trichocerca (Diurella) dixon-nuttalli',
#     'Trichocerca (Diurella) inermis',
#     'Trichocerca (Diurella) intermedia',
#     'Trichocerca (Diurella) porcellus',
#     'Trichocerca (Diurella) rousseleti',
#     'Trichocerca (Diurella) similis',
#     'Trichocerca (Diurella) sulcata',
#     'Trichocerca (Diurella) tenuior',
#     'Trichocerca (Diurella) tigris',
#     'Trichocerca (Diurella) weberi'],
#    'Trichocerca (Trichocerca)': ['Trichocerca (Trichocerca) bicristata',
#     'Trichocerca (Trichocerca) capucina',
#     'Trichocerca (Trichocerca) cylindrica',
#     'Trichocerca (Trichocerca) elongata',
#     'Trichocerca (Trichocerca) iernis',
#     'Trichocerca (Trichocerca) jenningsi',
#     'Trichocerca (Trichocerca) longiseta',
#     'Trichocerca (Trichocerca) lophoessa',
#     'Trichocerca (Trichocerca) macera',
#     'Trichocerca (Trichocerca) marina',
#     'Trichocerca (Trichocerca) pusilla',
#     'Trichocerca (Trichocerca) rattus',
#     'Trichocerca (Trichocerca) stylata']},
#   'Trichotridae': {'Macrochaetus': ['Macrochaetus collinsi',
#     'Macrochaetus subquadratus'],
#    'Trichotria': ['Trichotria pocillum',
#     'Trichotria tetractis',
#     'Trichotria truncata'],
#    'Wolga': ['Wolga spinifera']}},
#  'Tardigrada': {'Echiniscidae': {'Echiniscus': [],
#    'Echiniscus (Bryodelphax)': ['Echiniscus (Bryodelphax) parvulus'],
#    'Echiniscus (Echiniscus)': ['Echiniscus (Echiniscus) granulatus',
#     'Echiniscus (Echiniscus) mediantus',
#     'Echiniscus (Echiniscus) oihonnae',
#     'Echiniscus (Echiniscus) quadrispinosus',
#     'Echiniscus (Echiniscus) reticulatus',
#     'Echiniscus (Echiniscus) spitsbergensis',
#     'Echiniscus (Echiniscus) testudo',
#     'Echiniscus (Echiniscus) tympanista',
#     'Echiniscus (Echiniscus) viridis',
#     'Echiniscus (Echiniscus) wendti'],
#    'Echiniscus (Hypechiniscus)': ['Echiniscus (Hypechiniscus) gladiator']},
#   'Eutardigrada': {},
#   'Heterotardigrada': {},
#   'Macrobiotidae': {'Hypsibius': [],
#    'Hypsibius (Calohypsibius)': ['Hypsibius (Calohypsibius) ornatus'],
#    'Hypsibius (Diphascon)': ['Hypsibius (Diphascon) angustatus',
#     'Hypsibius (Diphascon) bullatus',
#     'Hypsibius (Diphascon) chilenensis',
#     'Hypsibius (Diphascon) oculatus',
#     'Hypsibius (Diphascon) scoticus',
#     'Hypsibius (Diphascon) spitzbergensis'],
#    'Hypsibius (Hypsibius)': ['Hypsibius (Hypsibius) arcticus',
#     'Hypsibius (Hypsibius) dujardini',
#     'Hypsibius (Hypsibius) oberhaeuseri'],
#    'Hypsibius (Isohypsibius)': ['Hypsibius (Isohypsibius) annulatus',
#     'Hypsibius (Isohypsibius) augusti',
#     'Hypsibius (Isohypsibius) papillifer',
#     'Hypsibius (Isohypsibius) prosostomus',
#     'Hypsibius (Isohypsibius) sattleri',
#     'Hypsibius (Isohypsibius) schaudinni',
#     'Hypsibius (Isohypsibius) tetradactyloides',
#     'Hypsibius (Isohypsibius) tuberculatus'],
#    'Macrobiotus': ['Macrobiotus ambiguus',
#     'Macrobiotus areolatus',
#     'Macrobiotus dispar',
#     'Macrobiotus echinogenitus',
#     'Macrobiotus hastatus',
#     'Macrobiotus hufelandii',
#     'Macrobiotus intermedius',
#     'Macrobiotus macronyx',
#     'Macrobiotus occidentalis',
#     'Macrobiotus pullari',
#     'Macrobiotus richtersi']},
#   'Milnesiidae': {'Milnesium': ['Milnesium tardigradum']}},
#  'Trematoda': {},
#  'Trichoptera': {'Apataniidae': {'Apatania': ['Apatania auricula',
#     'Apatania muliebris',
#     'Apatania nielseni',
#     'Apatania wallengreni']},
#   'Beraeidae': {'Beraea': ['Beraea maurus', 'Beraea pullata'],
#    'Beraeodes': ['Beraeodes minutus'],
#    'Ernodes': ['Ernodes articularis']},
#   'Brachycentridae': {'Brachycentrus': ['Brachycentrus subnubilus']},
#   'Drusinae': {},
#   'Ecnomidae': {'Ecnomus': ['Ecnomus tenellus']},
#   'Glossosomatidae': {'Agapetus': ['Agapetus delicatulus',
#     'Agapetus fuscipes',
#     'Agapetus ochripes'],
#    'Glossosoma': ['Glossosoma boltoni',
#     'Glossosoma conformis',
#     'Glossosoma intermedium'],
#    'Synagapetus': ['Synagapetus dubitans']},
#   'Goeridae': {'Goera': ['Goera pilosa'],
#    'Silo': ['Silo nigricornis', 'Silo pallipes']},
#   'Hydropsychidae': {'Cheumatopsyche': ['Cheumatopsyche lepida'],
#    'Diplectrona': ['Diplectrona felix'],
#    'Hydropsyche': ['Hydropsyche angustipennis',
#     'Hydropsyche bulgaromanorum',
#     'Hydropsyche contubernalis',
#     'Hydropsyche exocellata',
#     'Hydropsyche fulvipes',
#     'Hydropsyche instabilis',
#     'Hydropsyche pellucidula',
#     'Hydropsyche saxonica',
#     'Hydropsyche siltalai']},
#   'Hydropsychoidea': {},
#   'Hydroptilidae': {'Agraylea': ['Agraylea multipunctata',
#     'Agraylea sexmaculata'],
#    'Allotrichia': ['Allotrichia pallicornis'],
#    'Hydroptila': ['Hydroptila angulata',
#     'Hydroptila cornuta',
#     'Hydroptila forcipata',
#     'Hydroptila lotensis',
#     'Hydroptila martini',
#     'Hydroptila occulta',
#     'Hydroptila pulchricornis',
#     'Hydroptila simulans',
#     'Hydroptila sparsa',
#     'Hydroptila sylvestris',
#     'Hydroptila tigurina',
#     'Hydroptila tineoides',
#     'Hydroptila valesiaca',
#     'Hydroptila vectis'],
#    'Ithytrichia': ['Ithytrichia clavata', 'Ithytrichia lamellaris'],
#    'Orthotrichia': ['Orthotrichia angustella',
#     'Orthotrichia costalis',
#     'Orthotrichia tragetti'],
#    'Oxyethira': ['Oxyethira distinctella',
#     'Oxyethira falcata',
#     'Oxyethira flavicornis',
#     'Oxyethira frici',
#     'Oxyethira mirabilis',
#     'Oxyethira sagittifera',
#     'Oxyethira simplex',
#     'Oxyethira tristella'],
#    'Tricholeiochiton': ['Tricholeiochiton fagesii']},
#   'Lepidostomatidae': {'Crunoecia': ['Crunoecia irrorata'],
#    'Lasiocephala': ['Lasiocephala basalis'],
#    'Lepidostoma': ['Lepidostoma hirtum']},
#   'Leptoceridae': {'Adicella': ['Adicella filicornis', 'Adicella reducta'],
#    'Athripsodes': ['Athripsodes albifrons',
#     'Athripsodes aterrimus',
#     'Athripsodes bilineatus',
#     'Athripsodes cinereus',
#     'Athripsodes commutatus'],
#    'Ceraclea': ['Ceraclea albimacula',
#     'Ceraclea annulicornis',
#     'Ceraclea dissimilis',
#     'Ceraclea fulva',
#     'Ceraclea nigronervosa',
#     'Ceraclea senilis'],
#    'Erotesis': ['Erotesis baltica'],
#    'Leptocerus': ['Leptocerus interruptus',
#     'Leptocerus lusitanicus',
#     'Leptocerus tineiformis'],
#    'Mystacides': ['Mystacides azurea',
#     'Mystacides longicornis',
#     'Mystacides nigra'],
#    'Oecetis': ['Oecetis furva',
#     'Oecetis lacustris',
#     'Oecetis notata',
#     'Oecetis ochracea',
#     'Oecetis testacea'],
#    'Setodes': ['Setodes argentipunctellus', 'Setodes punctatus'],
#    'Triaenodes': ['Triaenodes bicolor'],
#    'Ylodes': ['Ylodes conspersus', 'Ylodes reuteri', 'Ylodes simulans']},
#   'Limnephilidae': {'Allogamus': ['Allogamus auricollis'],
#    'Anabolia': ['Anabolia nervosa', 'Anabolia brevipennis'],
#    'Chaetopteryx': ['Chaetopteryx villosa'],
#    'Drusus': ['Drusus annulatus'],
#    'Ecclisopteryx': ['Ecclisopteryx guttulata'],
#    'Glyphotaelius': ['Glyphotaelius pellucidus'],
#    'Grammotaulius': ['Grammotaulius nigropunctatus', 'Grammotaulius nitidus'],
#    'Halesus': ['Halesus digitatus', 'Halesus radiatus'],
#    'Hydatophylax': ['Hydatophylax infumatus'],
#    'Ironoquia': ['Ironoquia dubia'],
#    'Limnephilus': ['Limnephilus affinis',
#     'Limnephilus auricula',
#     'Limnephilus binotatus',
#     'Limnephilus bipunctatus',
#     'Limnephilus borealis',
#     'Limnephilus centralis',
#     'Limnephilus coenosus',
#     'Limnephilus decipiens',
#     'Limnephilus elegans',
#     'Limnephilus extricatus',
#     'Limnephilus flavicornis',
#     'Limnephilus fuscicornis',
#     'Limnephilus fuscinervis',
#     'Limnephilus griseus',
#     'Limnephilus hirsutus',
#     'Limnephilus ignavus',
#     'Limnephilus incisus',
#     'Limnephilus lunatus',
#     'Limnephilus luridus',
#     'Limnephilus marmoratus',
#     'Limnephilus nigriceps',
#     'Limnephilus pati',
#     'Limnephilus politus',
#     'Limnephilus rhombicus',
#     'Limnephilus sparsus',
#     'Limnephilus stigma',
#     'Limnephilus subcentralis',
#     'Limnephilus tauricus',
#     'Limnephilus vittatus'],
#    'Melampophylax': ['Melampophylax mucoreus'],
#    'Mesophylax': ['Mesophylax aspersus', 'Mesophylax impunctatus'],
#    'Micropterna': ['Micropterna lateralis', 'Micropterna sequax'],
#    'Nemotaulius': ['Nemotaulius punctatolineatus'],
#    'Potamophylax': ['Potamophylax cingulatus',
#     'Potamophylax latipennis',
#     'Potamophylax rotundipennis'],
#    'Rhadicoleptus': ['Rhadicoleptus alpestris'],
#    'Stenophylax': ['Stenophylax permistus', 'Stenophylax vibex']},
#   'Limnephilidae (including Apataniidae)': {},
#   'Limnephiloidea': {},
#   'Molannidae': {'Molanna': ['Molanna angustata', 'Molanna albicans']},
#   'Odontoceridae': {'Odontocerum': ['Odontocerum albicorne']},
#   'Philopotamidae': {'Chimarra': ['Chimarra marginata'],
#    'Philopotamus': ['Philopotamus montanus'],
#    'Wormaldia': ['Wormaldia mediana',
#     'Wormaldia occipitalis',
#     'Wormaldia subnigra']},
#   'Phryganeidae': {'Agrypnetes': ['Agrypnetes crassicornis'],
#    'Agrypnia': ['Agrypnia obsoleta',
#     'Agrypnia pagetana',
#     'Agrypnia picta',
#     'Agrypnia varia'],
#    'Hagenella': ['Hagenella clathrata'],
#    'Oligotricha': ['Oligotricha striata'],
#    'Phryganea': ['Phryganea bipunctata', 'Phryganea grandis'],
#    'Trichostegia': ['Trichostegia minor']},
#   'Polycentropodidae': {'Cyrnus': ['Cyrnus flavidus',
#     'Cyrnus insolutus',
#     'Cyrnus trimaculatus'],
#    'Holocentropus': ['Holocentropus dubius',
#     'Holocentropus picicornis',
#     'Holocentropus stagnalis'],
#    'Neureclipsis': ['Neureclipsis bimaculata'],
#    'Plectrocnemia': ['Plectrocnemia brevis',
#     'Plectrocnemia conspersa',
#     'Plectrocnemia geniculata'],
#    'Polycentropus': ['Polycentropus flavomaculatus',
#     'Polycentropus irroratus',
#     'Polycentropus kingi']},
#   'Psychomyiidae': {'Lype': ['Lype phaeopa', 'Lype reducta'],
#    'Metalype': ['Metalype fragilis'],
#    'Psychomyia': ['Psychomyia pusilla'],
#    'Tinodes': ['Tinodes assimilis',
#     'Tinodes dives',
#     'Tinodes maclachlani',
#     'Tinodes maculicornis',
#     'Tinodes pallidulus',
#     'Tinodes rostocki',
#     'Tinodes unicolor',
#     'Tinodes waeneri']},
#   'Psychomyiidae (including Ecnomidae)': {},
#   'Rhyacophilidae': {'Rhyacophila': ['Rhyacophila dorsalis',
#     'Rhyacophila munda',
#     'Rhyacophila obliterata',
#     'Rhyacophila fasciata']},
#   'Rhyacophilidae (including Glossosomatidae)': {},
#   'Rhyacophiloidea': {},
#   'Sericostomatidae': {'Notidobia': ['Notidobia ciliaris'],
#    'Sericostoma': ['Sericostoma personatum']}},
#  'Tricladida': {'Dendrocoelidae': {'Bdellocephala': ['Bdellocephala punctata'],
#    'Dendrocoelum': ['Dendrocoelum lacteum']},
#   'Dugesiidae': {'Dugesia': ['Dugesia lugubris',
#     'Dugesia polychroa',
#     'Dugesia tigrina',
#     'Dugesia gonocephala']},
#   'Paludicola': {},
#   'Planariidae': {'Crenobia': ['Crenobia alpina'],
#    'Phagocata': ['Phagocata vitta', 'Phagocata woodworthi'],
#    'Planaria': ['Planaria torva'],
#    'Polycelis': ['Polycelis felina', 'Polycelis nigra', 'Polycelis tenuis']},
#   'Planariidae (including Dugesiidae)': {}}}

# %%
# Reversing the dict is more usefull
# ie, get the taxonomy of a species


reverse_taxonomy = {}

for phylum in taxonomy:
    for group in taxonomy[phylum]:
        for genus in taxonomy[phylum][group]:
            for species in taxonomy[phylum][group][genus]:
                reverse_taxonomy[species] = [phylum, group, genus]
                
pickle_file_name = 'data/reverse_taxonomy.pkl'
output = open(pickle_file_name,'wb')
pickle.dump(reverse_taxonomy, output)
output.close()

tax = open('data/reverse_taxonomy_dict.txt','wt')
tax.write(str(reverse_taxonomy))
tax.close()

# %%
reverse_taxonomy
# Out:
# {'Ablabesmyia longistyla': ['Diptera', 'Tanypodinae', 'Ablabesmyia'],
#  'Ablabesmyia monilis': ['Diptera', 'Tanypodinae', 'Ablabesmyia'],
#  'Ablabesmyia phatta': ['Diptera', 'Tanypodinae', 'Ablabesmyia'],
#  'Acamptocladius reissi': ['Diptera', 'Orthocladiinae', 'Acamptocladius'],
#  'Acamptocladius submontanus': ['Diptera', 'Orthocladiinae', 'Acamptocladius'],
#  'Acanthocnema (Acanthocnema) nigrimana': ['Diptera',
#   'Scathophagidae',
#   'Acanthocnema (Acanthocnema)'],
#  'Acanthocnema (Clinoceroides) glaucescens': ['Diptera',
#   'Scathophagidae',
#   'Acanthocnema (Clinoceroides)'],
#  'Acanthocyclops robustus': ['Copepoda', 'Cyclopidae', 'Acanthocyclops'],
#  'Acanthocyclops sensitivus': ['Copepoda', 'Cyclopidae', 'Acanthocyclops'],
#  'Acanthocyclops venustus': ['Copepoda', 'Cyclopidae', 'Acanthocyclops'],
#  'Acanthocyclops vernalis': ['Copepoda', 'Cyclopidae', 'Acanthocyclops'],
#  'Acantholeberis  curvirostris': ['Cladocera',
#   'Acantholeberidae',
#   'Acantholeberis '],
#  'Acartia bifilosa': ['Copepoda', 'Acartiidae', 'Acartia'],
#  'Acartia clausi': ['Copepoda', 'Acartiidae', 'Acartia'],
#  'Acartia discaudata': ['Copepoda', 'Acartiidae', 'Acartia'],
#  'Acentria ephemerella': ['Lepidoptera', 'Pyralidae', 'Acentria'],
#  'Achalcus flavicollis': ['Diptera', 'Dolichopodidae', 'Achalcus'],
#  'Achromadora ruricola': ['Nematoda', 'Cyatholaimidae', 'Achromadora'],
#  'Achromadora terricola': ['Nematoda', 'Cyatholaimidae', 'Achromadora'],
#  'Achtheres percarum': ['Copepoda', 'Lernaeopodidae', 'Achtheres'],
#  'Achyrolimonia decemmaculata': ['Diptera', 'Limoniidae', 'Achyrolimonia'],
#  'Acilius canaliculatus': ['Coleoptera', 'Dytiscidae', 'Acilius'],
#  'Acilius sulcatus': ['Coleoptera', 'Dytiscidae', 'Acilius'],
#  'Acricotopus lucens': ['Diptera', 'Orthocladiinae', 'Acricotopus'],
#  'Acroloxus lacustris': ['Gastropoda', 'Acroloxidae', 'Acroloxus'],
#  'Acroperus  angustatus': ['Cladocera', 'Chydoridae', 'Acroperus '],
#  'Acroperus  harpae': ['Cladocera', 'Chydoridae', 'Acroperus '],
#  'Acropsilus niger': ['Diptera', 'Dolichopodidae', 'Acropsilus'],
#  'Actinolaimus macrolaimus': ['Nematoda', 'Dorylaimidae', 'Actinolaimus'],
#  'Ademon decrescens': ['Hymenoptera', 'Braconidae', 'Ademon'],
#  'Adicella filicornis': ['Trichoptera', 'Leptoceridae', 'Adicella'],
#  'Adicella reducta': ['Trichoptera', 'Leptoceridae', 'Adicella'],
#  'Adineta barbata': ['Rotifera', 'Adinetidae', 'Adineta'],
#  'Adineta gracilis': ['Rotifera', 'Adinetidae', 'Adineta'],
#  'Adineta oculata': ['Rotifera', 'Adinetidae', 'Adineta'],
#  'Adineta tuberculosa': ['Rotifera', 'Adinetidae', 'Adineta'],
#  'Adineta vaga': ['Rotifera', 'Adinetidae', 'Adineta'],
#  'Aedes (Aedes) cinereus': ['Diptera', 'Culicidae', 'Aedes (Aedes)'],
#  'Aedes (Aedimorphus) vexans': ['Diptera', 'Culicidae', 'Aedes (Aedimorphus)'],
#  'Aeolosoma beddardi': ['Aphanoneura', 'Aeolosomatidae', 'Aeolosoma'],
#  'Aeolosoma headleyi': ['Aphanoneura', 'Aeolosomatidae', 'Aeolosoma'],
#  'Aeolosoma hemprichi': ['Aphanoneura', 'Aeolosomatidae', 'Aeolosoma'],
#  'Aeolosoma quaternarium': ['Aphanoneura', 'Aeolosomatidae', 'Aeolosoma'],
#  'Aeolosoma tenebrarum': ['Aphanoneura', 'Aeolosomatidae', 'Aeolosoma'],
#  'Aeolosoma variegatum': ['Aphanoneura', 'Aeolosomatidae', 'Aeolosoma'],
#  'Aeshna affinis': ['Odonata', 'Aeshnidae', 'Aeshna'],
#  'Aeshna caerulea': ['Odonata', 'Aeshnidae', 'Aeshna'],
#  'Aeshna cyanea': ['Odonata', 'Aeshnidae', 'Aeshna'],
#  'Aeshna grandis': ['Odonata', 'Aeshnidae', 'Aeshna'],
#  'Aeshna isosceles': ['Odonata', 'Aeshnidae', 'Aeshna'],
#  'Aeshna juncea': ['Odonata', 'Aeshnidae', 'Aeshna'],
#  'Aeshna mixta': ['Odonata', 'Aeshnidae', 'Aeshna'],
#  'Agabus (Acatodes) arcticus': ['Coleoptera',
#   'Dytiscidae',
#   'Agabus (Acatodes)'],
#  'Agabus (Acatodes) congener': ['Coleoptera',
#   'Dytiscidae',
#   'Agabus (Acatodes)'],
#  'Agabus (Acatodes) sturmii': ['Coleoptera',
#   'Dytiscidae',
#   'Agabus (Acatodes)'],
#  'Agabus (Agabus) labiatus': ['Coleoptera', 'Dytiscidae', 'Agabus (Agabus)'],
#  'Agabus (Agabus) uliginosus': ['Coleoptera', 'Dytiscidae', 'Agabus (Agabus)'],
#  'Agabus (Agabus) undulatus': ['Coleoptera', 'Dytiscidae', 'Agabus (Agabus)'],
#  'Agabus (Gaurodytes) affinis': ['Coleoptera',
#   'Dytiscidae',
#   'Agabus (Gaurodytes)'],
#  'Agabus (Gaurodytes) biguttatus': ['Coleoptera',
#   'Dytiscidae',
#   'Agabus (Gaurodytes)'],
#  'Agabus (Gaurodytes) bipustulatus': ['Coleoptera',
#   'Dytiscidae',
#   'Agabus (Gaurodytes)'],
#  'Agabus (Gaurodytes) brunneus': ['Coleoptera',
#   'Dytiscidae',
#   'Agabus (Gaurodytes)'],
#  'Agabus (Gaurodytes) conspersus': ['Coleoptera',
#   'Dytiscidae',
#   'Agabus (Gaurodytes)'],
#  'Agabus (Gaurodytes) didymus': ['Coleoptera',
#   'Dytiscidae',
#   'Agabus (Gaurodytes)'],
#  'Agabus (Gaurodytes) guttatus': ['Coleoptera',
#   'Dytiscidae',
#   'Agabus (Gaurodytes)'],
#  'Agabus (Gaurodytes) melanarius': ['Coleoptera',
#   'Dytiscidae',
#   'Agabus (Gaurodytes)'],
#  'Agabus (Gaurodytes) nebulosus': ['Coleoptera',
#   'Dytiscidae',
#   'Agabus (Gaurodytes)'],
#  'Agabus (Gaurodytes) paludosus': ['Coleoptera',
#   'Dytiscidae',
#   'Agabus (Gaurodytes)'],
#  'Agabus (Gaurodytes) striolatus': ['Coleoptera',
#   'Dytiscidae',
#   'Agabus (Gaurodytes)'],
#  'Agabus (Gaurodytes) unguicularis': ['Coleoptera',
#   'Dytiscidae',
#   'Agabus (Gaurodytes)'],
#  'Agapetus delicatulus': ['Trichoptera', 'Glossosomatidae', 'Agapetus'],
#  'Agapetus fuscipes': ['Trichoptera', 'Glossosomatidae', 'Agapetus'],
#  'Agapetus ochripes': ['Trichoptera', 'Glossosomatidae', 'Agapetus'],
#  'Agraylea multipunctata': ['Trichoptera', 'Hydroptilidae', 'Agraylea'],
#  'Agraylea sexmaculata': ['Trichoptera', 'Hydroptilidae', 'Agraylea'],
#  'Agrenia bidenticulata': ['Collembola', 'Isotomidae', 'Agrenia'],
#  'Agriotypus armatus': ['Hymenoptera', 'Ichneumonidae', 'Agriotypus'],
#  'Agrypnetes crassicornis': ['Trichoptera', 'Phryganeidae', 'Agrypnetes'],
#  'Agrypnia obsoleta': ['Trichoptera', 'Phryganeidae', 'Agrypnia'],
#  'Agrypnia pagetana': ['Trichoptera', 'Phryganeidae', 'Agrypnia'],
#  'Agrypnia picta': ['Trichoptera', 'Phryganeidae', 'Agrypnia'],
#  'Agrypnia varia': ['Trichoptera', 'Phryganeidae', 'Agrypnia'],
#  'Alaimus primitivus': ['Nematoda', 'Alaimidae', 'Alaimus'],
#  'Alainites muticus': ['Ephemeroptera', 'Baetidae', 'Alainites'],
#  'Albaxona (Vietsaxona) lundbladi': ['Hydracarina',
#   'Aturidae',
#   'Albaxona (Vietsaxona)'],
#  'Albertia naidis': ['Rotifera', 'Dicranophoridae', 'Albertia'],
#  'Albia stationis': ['Hydracarina', 'Aturidae', 'Albia'],
#  'Alboglossiphonia heteroclita': ['Hirudinea',
#   'Glossiphoniidae',
#   'Alboglossiphonia'],
#  'Allogamus auricollis': ['Trichoptera', 'Limnephilidae', 'Allogamus'],
#  'Allohelea tessellata': ['Diptera', 'Ceratopogonidae', 'Allohelea'],
#  'Allolobophora chlorotica': ['Oligochaeta', 'Lumbricidae', 'Allolobophora'],
#  'Allolobophora rosea': ['Oligochaeta', 'Lumbricidae', 'Allolobophora'],
#  'Allotrichia pallicornis': ['Trichoptera', 'Hydroptilidae', 'Allotrichia'],
#  'Alluaudomyia riparia': ['Diptera', 'Ceratopogonidae', 'Alluaudomyia'],
#  'Alona  affinis': ['Cladocera', 'Chydoridae', 'Alona '],
#  'Alona  costata': ['Cladocera', 'Chydoridae', 'Alona '],
#  'Alona  elegans': ['Cladocera', 'Chydoridae', 'Alona '],
#  'Alona  guttata': ['Cladocera', 'Chydoridae', 'Alona '],
#  'Alona  intermedia': ['Cladocera', 'Chydoridae', 'Alona '],
#  'Alona  karelica': ['Cladocera', 'Chydoridae', 'Alona '],
#  'Alona  quadrangularis': ['Cladocera', 'Chydoridae', 'Alona '],
#  'Alona  rustica': ['Cladocera', 'Chydoridae', 'Alona '],
#  'Alona  weltneri': ['Cladocera', 'Chydoridae', 'Alona '],
#  'Alonella  excisa': ['Cladocera', 'Chydoridae', 'Alonella '],
#  'Alonella  exigua': ['Cladocera', 'Chydoridae', 'Alonella '],
#  'Alonella  nana': ['Cladocera', 'Chydoridae', 'Alonella '],
#  'Alonopsis  elongata': ['Cladocera', 'Chydoridae', 'Alonopsis '],
#  'Amalorrhynchus melanarius': ['Coleoptera',
#   'Curculionidae',
#   'Amalorrhynchus'],
#  'Ameletus inopinatus': ['Ephemeroptera', 'Ameletidae', 'Ameletus'],
#  'Amphinemura standfussi': ['Plecoptera', 'Nemouridae', 'Amphinemura'],
#  'Amphinemura sulcicollis': ['Plecoptera', 'Nemouridae', 'Amphinemura'],
#  'Anabolia brevipennis': ['Trichoptera', 'Limnephilidae', 'Anabolia'],
#  'Anabolia nervosa': ['Trichoptera', 'Limnephilidae', 'Anabolia'],
#  'Anacaena bipustulata': ['Coleoptera', 'Hydrophilidae', 'Anacaena'],
#  'Anacaena globulus': ['Coleoptera', 'Hydrophilidae', 'Anacaena'],
#  'Anacaena limbata': ['Coleoptera', 'Hydrophilidae', 'Anacaena'],
#  'Anacaena lutescens': ['Coleoptera', 'Hydrophilidae', 'Anacaena'],
#  'Anagrus incarnatus': ['Hymenoptera', 'Mymaridae', 'Anagrus'],
#  'Anasimyia contracta': ['Diptera', 'Syrphidae', 'Anasimyia'],
#  'Anasimyia interpuncta': ['Diptera', 'Syrphidae', 'Anasimyia'],
#  'Anasimyia lineata': ['Diptera', 'Syrphidae', 'Anasimyia'],
#  'Anasimyia lunulata': ['Diptera', 'Syrphidae', 'Anasimyia'],
#  'Anasimyia transfuga': ['Diptera', 'Syrphidae', 'Anasimyia'],
#  'Anatopynia plumipes': ['Diptera', 'Tanypodinae', 'Anatopynia'],
#  'Anax imperator': ['Odonata', 'Aeshnidae', 'Anax'],
#  'Anax junius': ['Odonata', 'Aeshnidae', 'Anax'],
#  'Anax parthenope': ['Odonata', 'Aeshnidae', 'Anax'],
#  'Anchistropus  emarginatus': ['Cladocera', 'Chydoridae', 'Anchistropus '],
#  'Ancylus fluviatilis': ['Gastropoda', 'Planorbidae', 'Ancylus'],
#  'Anepsiomyia flaviventris': ['Diptera', 'Dolichopodidae', 'Anepsiomyia'],
#  'Anisus (Anisus) leucostoma': ['Gastropoda',
#   'Planorbidae',
#   'Anisus (Anisus)'],
#  'Anisus (Anisus) spirorbis': ['Gastropoda', 'Planorbidae', 'Anisus (Anisus)'],
#  'Anisus (Disculifer) vortex': ['Gastropoda',
#   'Planorbidae',
#   'Anisus (Disculifer)'],
#  'Anisus (Disculifer) vorticulus': ['Gastropoda',
#   'Planorbidae',
#   'Anisus (Disculifer)'],
#  'Anodonta anatina': ['Bivalvia', 'Unionidae', 'Anodonta'],
#  'Anodonta cygnea': ['Bivalvia', 'Unionidae', 'Anodonta'],
#  'Anodonta woodiana': ['Bivalvia', 'Unionidae', 'Anodonta'],
#  'Anopheles (Anopheles) algeriensis': ['Diptera',
#   'Culicidae',
#   'Anopheles (Anopheles)'],
#  'Anopheles (Anopheles) atroparvus': ['Diptera',
#   'Culicidae',
#   'Anopheles (Anopheles)'],
#  'Anopheles (Anopheles) claviger': ['Diptera',
#   'Culicidae',
#   'Anopheles (Anopheles)'],
#  'Anopheles (Anopheles) daciae': ['Diptera',
#   'Culicidae',
#   'Anopheles (Anopheles)'],
#  'Anopheles (Anopheles) messeae': ['Diptera',
#   'Culicidae',
#   'Anopheles (Anopheles)'],
#  'Anopheles (Anopheles) plumbeus': ['Diptera',
#   'Culicidae',
#   'Anopheles (Anopheles)'],
#  'Antichaeta analis': ['Diptera', 'Sciomyzidae', 'Antichaeta'],
#  'Antichaeta atriseta': ['Diptera', 'Sciomyzidae', 'Antichaeta'],
#  'Antichaeta brevipennis': ['Diptera', 'Sciomyzidae', 'Antichaeta'],
#  'Antichaeta obliviosa': ['Diptera', 'Sciomyzidae', 'Antichaeta'],
#  'Antocha (Antocha) vitripennis': ['Diptera',
#   'Limoniidae',
#   'Antocha (Antocha)'],
#  'Antrobathynella stammeri': ['Bathynellacea',
#   'unspecified',
#   'Antrobathynella'],
#  'Anuraeopsis fissa': ['Rotifera', 'Brachionidae', 'Anuraeopsis'],
#  'Anurida tullbergi': ['Collembola', 'Neanuridae', 'Anurida'],
#  'Apatania auricula': ['Trichoptera', 'Apataniidae', 'Apatania'],
#  'Apatania muliebris': ['Trichoptera', 'Apataniidae', 'Apatania'],
#  'Apatania nielseni': ['Trichoptera', 'Apataniidae', 'Apatania'],
#  'Apatania wallengreni': ['Trichoptera', 'Apataniidae', 'Apatania'],
#  'Aphanolaimus aquaticus': ['Nematoda', 'Camacolaimidae', 'Aphanolaimus'],
#  'Aphanolaimus attentus': ['Nematoda', 'Camacolaimidae', 'Aphanolaimus'],
#  'Aphelenchoides parietinus': ['Nematoda',
#   'Aphelenchoididae',
#   'Aphelenchoides'],
#  'Aphelenchoides saprophilus': ['Nematoda',
#   'Aphelenchoididae',
#   'Aphelenchoides'],
#  'Aphelocheirus aestivalis': ['Hemiptera', 'Aphelocheiridae', 'Aphelocheirus'],
#  'Aphrosylus mitis': ['Diptera', 'Dolichopodidae', 'Aphrosylus'],
#  'Aplexa hypnorum': ['Gastropoda', 'Physidae', 'Aplexa'],
#  'Aporcelaimus obscurus': ['Nematoda', 'Dorylaimidae', 'Aporcelaimus'],
#  'Aporrectodea caliginosa': ['Oligochaeta', 'Lumbricidae', 'Aporrectodea'],
#  'Apsectrotanypus trifascipennis': ['Diptera',
#   'Tanypodinae',
#   'Apsectrotanypus'],
#  'Aquarius najas': ['Hemiptera', 'Gerridae', 'Aquarius'],
#  'Aquarius paludum': ['Hemiptera', 'Gerridae', 'Aquarius'],
#  'Arcteonais lomondi': ['Oligochaeta', 'Naididae', 'Arcteonais'],
#  'Arctoconopa melampodia': ['Diptera', 'Limoniidae', 'Arctoconopa'],
#  'Arctocorisa carinata': ['Hemiptera', 'Corixidae', 'Arctocorisa'],
#  'Arctocorisa germari': ['Hemiptera', 'Corixidae', 'Arctocorisa'],
#  'Arctodiaptomus (Arctodiaptomus) laticeps': ['Copepoda',
#   'Diaptomidae',
#   'Arctodiaptomus (Arctodiaptomus)'],
#  'Arctodiaptomus (Arctodiaptomus) wierzejskii': ['Copepoda',
#   'Diaptomidae',
#   'Arctodiaptomus (Arctodiaptomus)'],
#  'Arctodiaptomus (Rhabdodiaptomus) alpinus': ['Copepoda',
#   'Diaptomidae',
#   'Arctodiaptomus (Rhabdodiaptomus)'],
#  'Arctopelopia barbitarsis': ['Diptera', 'Tanypodinae', 'Arctopelopia'],
#  'Arctopelopia griseipennis': ['Diptera', 'Tanypodinae', 'Arctopelopia'],
#  'Arctopelopia melanosoma': ['Diptera', 'Tanypodinae', 'Arctopelopia'],
#  'Arctophila superbiens': ['Diptera', 'Syrphidae', 'Arctophila'],
#  'Argulus coregoni': ['Branchiura', 'unspecified', 'Argulus'],
#  'Argulus foliaceus': ['Branchiura', 'unspecified', 'Argulus'],
#  'Argyra argentina': ['Diptera', 'Dolichopodidae', 'Argyra'],
#  'Argyra argyria': ['Diptera', 'Dolichopodidae', 'Argyra'],
#  'Argyra diaphana': ['Diptera', 'Dolichopodidae', 'Argyra'],
#  'Argyra elongata': ['Diptera', 'Dolichopodidae', 'Argyra'],
#  'Argyra ilonae': ['Diptera', 'Dolichopodidae', 'Argyra'],
#  'Argyra leucocephala': ['Diptera', 'Dolichopodidae', 'Argyra'],
#  'Argyra perplexa': ['Diptera', 'Dolichopodidae', 'Argyra'],
#  'Argyra vestita': ['Diptera', 'Dolichopodidae', 'Argyra'],
#  'Argyroneta aquatica': ['Araneae', 'unspecified', 'Argyroneta'],
#  'Arrenurus (Arrenurus) abbreviator': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Arrenurus)'],
#  'Arrenurus (Arrenurus) affinis': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Arrenurus)'],
#  'Arrenurus (Arrenurus) albator': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Arrenurus)'],
#  'Arrenurus (Arrenurus) batillifer': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Arrenurus)'],
#  'Arrenurus (Arrenurus) bicuspidator': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Arrenurus)'],
#  'Arrenurus (Arrenurus) bruzelii': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Arrenurus)'],
#  'Arrenurus (Arrenurus) claviger': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Arrenurus)'],
#  'Arrenurus (Arrenurus) compactus': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Arrenurus)'],
#  'Arrenurus (Arrenurus) crassicaudatus': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Arrenurus)'],
#  'Arrenurus (Arrenurus) crenatus': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Arrenurus)'],
#  'Arrenurus (Arrenurus) cuspidifer': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Arrenurus)'],
#  'Arrenurus (Arrenurus) fimbriatus': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Arrenurus)'],
#  'Arrenurus (Arrenurus) latus': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Arrenurus)'],
#  'Arrenurus (Arrenurus) leuckarti': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Arrenurus)'],
#  'Arrenurus (Arrenurus) maculator': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Arrenurus)'],
#  'Arrenurus (Arrenurus) neumani': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Arrenurus)'],
#  'Arrenurus (Arrenurus) nobilis': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Arrenurus)'],
#  'Arrenurus (Arrenurus) ornatus': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Arrenurus)'],
#  'Arrenurus (Arrenurus) robustus': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Arrenurus)'],
#  'Arrenurus (Arrenurus) tricuspidator': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Arrenurus)'],
#  'Arrenurus (Arrenurus) virens': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Arrenurus)'],
#  'Arrenurus (Megaluracarus) adnatus': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Megaluracarus)'],
#  'Arrenurus (Megaluracarus) buccinator': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Megaluracarus)'],
#  'Arrenurus (Megaluracarus) cylindratus': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Megaluracarus)'],
#  'Arrenurus (Megaluracarus) geminus': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Megaluracarus)'],
#  'Arrenurus (Megaluracarus) globator': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Megaluracarus)'],
#  'Arrenurus (Megaluracarus) mediorotundatus': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Megaluracarus)'],
#  'Arrenurus (Megaluracarus) membranator': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Megaluracarus)'],
#  'Arrenurus (Megaluracarus) muelleri': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Megaluracarus)'],
#  'Arrenurus (Megaluracarus) pyriformis': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Megaluracarus)'],
#  'Arrenurus (Megaluracarus) scourfieldi': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Megaluracarus)'],
#  'Arrenurus (Megaluracarus) securiformis': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Megaluracarus)'],
#  'Arrenurus (Megaluracarus) soari': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Megaluracarus)'],
#  'Arrenurus (Megaluracarus) stjoerdalensis': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Megaluracarus)'],
#  'Arrenurus (Megaluracarus) zachariae': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Megaluracarus)'],
#  'Arrenurus (Micruracarus) bifidicodulus': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Micruracarus)'],
#  'Arrenurus (Micruracarus) bipapillosus': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Micruracarus)'],
#  'Arrenurus (Micruracarus) biscissus': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Micruracarus)'],
#  'Arrenurus (Micruracarus) britannorum': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Micruracarus)'],
#  'Arrenurus (Micruracarus) forpicatus': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Micruracarus)'],
#  'Arrenurus (Micruracarus) inexploratus': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Micruracarus)'],
#  'Arrenurus (Micruracarus) integrator': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Micruracarus)'],
#  'Arrenurus (Micruracarus) longiusculus': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Micruracarus)'],
#  'Arrenurus (Micruracarus) novus': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Micruracarus)'],
#  'Arrenurus (Micruracarus) octagonus': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Micruracarus)'],
#  'Arrenurus (Micruracarus) perforatus': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Micruracarus)'],
#  'Arrenurus (Micruracarus) sculptus': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Micruracarus)'],
#  'Arrenurus (Micruracarus) sinuator': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Micruracarus)'],
#  'Arrenurus (Truncaturus) fontinalis': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Truncaturus)'],
#  'Arrenurus (Truncaturus) knauthei': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Truncaturus)'],
#  'Arrenurus (Truncaturus) nodosus': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Truncaturus)'],
#  'Arrenurus (Truncaturus) stecki': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Truncaturus)'],
#  'Arrenurus (Truncaturus) truncatellus': ['Hydracarina',
#   'Arrenuridae',
#   'Arrenurus (Truncaturus)'],
#  'Arrenurus curtus': ['Hydracarina', 'Arrenuridae', 'Arrenurus'],
#  'Arrenurus luteus': ['Hydracarina', 'Arrenuridae', 'Arrenurus'],
#  'Arrenurus mollis': ['Hydracarina', 'Arrenuridae', 'Arrenurus'],
#  'Artemia salina': ['Anostraca', 'unspecified', 'Artemia'],
#  'Arthroplea congener': ['Ephemeroptera', 'Arthropleidae', 'Arthroplea'],
#  'Ascomorpha ecaudis': ['Rotifera', 'Gastropodidae', 'Ascomorpha'],
#  'Ascomorpha ovalis': ['Rotifera', 'Gastropodidae', 'Ascomorpha'],
#  'Ascomorpha saltans': ['Rotifera', 'Gastropodidae', 'Ascomorpha'],
#  'Ascomorphella volvocicola': ['Rotifera', 'Trichocercidae', 'Ascomorphella'],
#  'Asellus aquaticus': ['Isopoda', 'Asellidae', 'Asellus'],
#  'Aspelta circinator': ['Rotifera', 'Dicranophoridae', 'Aspelta'],
#  'Aspelta clydona': ['Rotifera', 'Dicranophoridae', 'Aspelta'],
#  'Asplanchna (Asplanchna) herricki': ['Rotifera',
#   'Asplanchnidae',
#   'Asplanchna (Asplanchna)'],
#  'Asplanchna (Asplanchna) priodonta': ['Rotifera',
#   'Asplanchnidae',
#   'Asplanchna (Asplanchna)'],
#  'Asplanchna (Asplanchnella) brightwelli': ['Rotifera',
#   'Asplanchnidae',
#   'Asplanchna (Asplanchnella)'],
#  'Asplanchna (Asplanchnella) girodi': ['Rotifera',
#   'Asplanchnidae',
#   'Asplanchna (Asplanchnella)'],
#  'Asplanchna (Asplanchnella) intermedia': ['Rotifera',
#   'Asplanchnidae',
#   'Asplanchna (Asplanchnella)'],
#  'Asplanchna (Asplanchnella) sieboldi': ['Rotifera',
#   'Asplanchnidae',
#   'Asplanchna (Asplanchnella)'],
#  'Asplanchnopus multiceps': ['Rotifera', 'Asplanchnidae', 'Asplanchnopus'],
#  'Assiminea grayana': ['Gastropoda', 'Assimineidae', 'Assiminea'],
#  'Astacus astacus': ['Decapoda', 'Astacidae', 'Astacus'],
#  'Astacus leptodactylus': ['Decapoda', 'Astacidae', 'Astacus'],
#  'Astegistes pilosus': ['Oribatei', 'Astegistidae', 'Astegistes'],
#  'Atherix ibis': ['Diptera', 'Athericidae', 'Atherix'],
#  'Athripsodes albifrons': ['Trichoptera', 'Leptoceridae', 'Athripsodes'],
#  'Athripsodes aterrimus': ['Trichoptera', 'Leptoceridae', 'Athripsodes'],
#  'Athripsodes bilineatus': ['Trichoptera', 'Leptoceridae', 'Athripsodes'],
#  'Athripsodes cinereus': ['Trichoptera', 'Leptoceridae', 'Athripsodes'],
#  'Athripsodes commutatus': ['Trichoptera', 'Leptoceridae', 'Athripsodes'],
#  'Atractides (Atractides) denticulatus': ['Hydracarina',
#   'Hygrobatidae',
#   'Atractides (Atractides)'],
#  'Atractides (Atractides) elongatus': ['Hydracarina',
#   'Hygrobatidae',
#   'Atractides (Atractides)'],
#  'Atractides (Atractides) gibberipalpis': ['Hydracarina',
#   'Hygrobatidae',
#   'Atractides (Atractides)'],
#  'Atractides (Atractides) latipalpis': ['Hydracarina',
#   'Hygrobatidae',
#   'Atractides (Atractides)'],
#  'Atractides (Atractides) longipes': ['Hydracarina',
#   'Hygrobatidae',
#   'Atractides (Atractides)'],
#  'Atractides (Atractides) magnirostris': ['Hydracarina',
#   'Hygrobatidae',
#   'Atractides (Atractides)'],
#  'Atractides (Atractides) nodipalpis': ['Hydracarina',
#   'Hygrobatidae',
#   'Atractides (Atractides)'],
#  'Atractides (Atractides) pachydermis': ['Hydracarina',
#   'Hygrobatidae',
#   'Atractides (Atractides)'],
#  'Atractides (Atractides) pavesii': ['Hydracarina',
#   'Hygrobatidae',
#   'Atractides (Atractides)'],
#  'Atractides (Atractides) spinipes': ['Hydracarina',
#   'Hygrobatidae',
#   'Atractides (Atractides)'],
#  'Atractides (Atractides) tener': ['Hydracarina',
#   'Hygrobatidae',
#   'Atractides (Atractides)'],
#  'Atractides (Octomegapus) octoporus': ['Hydracarina',
#   'Hygrobatidae',
#   'Atractides (Octomegapus)'],
#  'Atrichobrunettia (Mirousiella) angustipennis': ['Diptera',
#   'Psychodidae',
#   'Atrichobrunettia (Mirousiella)'],
#  'Atrichopogon (Atrichopogon) aethiops': ['Diptera',
#   'Ceratopogonidae',
#   'Atrichopogon (Atrichopogon)'],
#  'Atrichopogon (Atrichopogon) brunnipes': ['Diptera',
#   'Ceratopogonidae',
#   'Atrichopogon (Atrichopogon)'],
#  'Atrichopogon (Atrichopogon) fuscus': ['Diptera',
#   'Ceratopogonidae',
#   'Atrichopogon (Atrichopogon)'],
#  'Atrichopogon (Atrichopogon) minutus': ['Diptera',
#   'Ceratopogonidae',
#   'Atrichopogon (Atrichopogon)'],
#  'Atrichopogon (Atrichopogon) pavidus': ['Diptera',
#   'Ceratopogonidae',
#   'Atrichopogon (Atrichopogon)'],
#  'Atrichopogon (Lophomyidium) rostratus': ['Diptera',
#   'Ceratopogonidae',
#   'Atrichopogon (Lophomyidium)'],
#  'Atrichopogon (Meloehelea) lucorum': ['Diptera',
#   'Ceratopogonidae',
#   'Atrichopogon (Meloehelea)'],
#  'Atrichopogon (Meloehelea) oedemerarum': ['Diptera',
#   'Ceratopogonidae',
#   'Atrichopogon (Meloehelea)'],
#  'Atrichopogon (Meloehelea) winnertzi': ['Diptera',
#   'Ceratopogonidae',
#   'Atrichopogon (Meloehelea)'],
#  'Atrichopogon (Psammopogon) muelleri': ['Diptera',
#   'Ceratopogonidae',
#   'Atrichopogon (Psammopogon)'],
#  'Atrichopogon (Psilokempia) appendiculatus': ['Diptera',
#   'Ceratopogonidae',
#   'Atrichopogon (Psilokempia)'],
#  'Atrichopogon (Psilokempia) forcipatus': ['Diptera',
#   'Ceratopogonidae',
#   'Atrichopogon (Psilokempia)'],
#  'Atrichops crassipes': ['Diptera', 'Athericidae', 'Atrichops'],
#  'Atrochus tentaculatus': ['Rotifera', 'Atrochidae', 'Atrochus'],
#  'Attheyella (Attheyella) crassa': ['Copepoda',
#   'Canthocamptidae',
#   'Attheyella (Attheyella)'],
#  'Attheyella (Brehmiella) dentata': ['Copepoda',
#   'Canthocamptidae',
#   'Attheyella (Brehmiella)'],
#  'Attheyella (Brehmiella) trispinosa': ['Copepoda',
#   'Canthocamptidae',
#   'Attheyella (Brehmiella)'],
#  'Attheyella (Brehmiella) wulmeri': ['Copepoda',
#   'Canthocamptidae',
#   'Attheyella (Brehmiella)'],
#  'Attheyella (Elaphoidella) bidens': ['Copepoda',
#   'Canthocamptidae',
#   'Attheyella (Elaphoidella)'],
#  'Attheyella (Elaphoidella) gracilis': ['Copepoda',
#   'Canthocamptidae',
#   'Attheyella (Elaphoidella)'],
#  'Aturus brachypus': ['Hydracarina', 'Aturidae', 'Aturus'],
#  'Aturus crinitus': ['Hydracarina', 'Aturidae', 'Aturus'],
#  'Aturus intermedius': ['Hydracarina', 'Aturidae', 'Aturus'],
#  'Aturus scaber': ['Hydracarina', 'Aturidae', 'Aturus'],
#  'Atylotus fulvus': ['Diptera', 'Tabanidae', 'Atylotus'],
#  'Atylotus latistriatus': ['Diptera', 'Tabanidae', 'Atylotus'],
#  'Atylotus plebeius': ['Diptera', 'Tabanidae', 'Atylotus'],
#  'Atylotus rusticus': ['Diptera', 'Tabanidae', 'Atylotus'],
#  'Atypophthalmus inustus': ['Diptera', 'Limoniidae', 'Atypophthalmus'],
#  'Augyles hispidulus': ['Coleoptera', 'Heteroceridae', 'Augyles'],
#  'Augyles maritimus': ['Coleoptera', 'Heteroceridae', 'Augyles'],
#  'Aulacochthebius exaratus': ['Coleoptera', 'Hydraenidae', 'Aulacochthebius'],
#  'Aulodrilus limnobius': ['Oligochaeta', 'Tubificidae', 'Aulodrilus'],
#  'Aulodrilus pigueti': ['Oligochaeta', 'Tubificidae', 'Aulodrilus'],
#  'Aulodrilus pluriseta': ['Oligochaeta', 'Tubificidae', 'Aulodrilus'],
#  'Austrolimnophila (Austrolimnophila) ochracea': ['Diptera',
#   'Limoniidae',
#   'Austrolimnophila (Austrolimnophila)'],
#  'Austropotamobius pallipes': ['Decapoda', 'Astacidae', 'Austropotamobius'],
#  'Axonopsis (Axonopsis) complanata': ['Hydracarina',
#   'Aturidae',
#   'Axonopsis (Axonopsis)'],
#  'Axonopsis (Hexaxonopsis) romijni': ['Hydracarina',
#   'Aturidae',
#   'Axonopsis (Hexaxonopsis)'],
#  'Baetis buceratus': ['Ephemeroptera', 'Baetidae', 'Baetis'],
#  'Baetis fuscatus': ['Ephemeroptera', 'Baetidae', 'Baetis'],
#  'Baetis rhodani': ['Ephemeroptera', 'Baetidae', 'Baetis'],
#  'Baetis scambus': ['Ephemeroptera', 'Baetidae', 'Baetis'],
#  'Baetis vernus': ['Ephemeroptera', 'Baetidae', 'Baetis'],
#  'Bagous (Abagous) glabrirostris': ['Coleoptera',
#   'Curculionidae',
#   'Bagous (Abagous)'],
#  'Bagous (Abagous) lutosus': ['Coleoptera',
#   'Curculionidae',
#   'Bagous (Abagous)'],
#  'Bagous (Abagous) lutulentus': ['Coleoptera',
#   'Curculionidae',
#   'Bagous (Abagous)'],
#  'Bagous (Abagous) puncticollis': ['Coleoptera',
#   'Curculionidae',
#   'Bagous (Abagous)'],
#  'Bagous (Abagous) robustus': ['Coleoptera',
#   'Curculionidae',
#   'Bagous (Abagous)'],
#  'Bagous (Bagous) argillaceus': ['Coleoptera',
#   'Curculionidae',
#   'Bagous (Bagous)'],
#  'Bagous (Bagous) binodulus': ['Coleoptera',
#   'Curculionidae',
#   'Bagous (Bagous)'],
#  'Bagous (Bagous) brevis': ['Coleoptera', 'Curculionidae', 'Bagous (Bagous)'],
#  'Bagous (Bagous) collignensis': ['Coleoptera',
#   'Curculionidae',
#   'Bagous (Bagous)'],
#  'Bagous (Bagous) czwalinae': ['Coleoptera',
#   'Curculionidae',
#   'Bagous (Bagous)'],
#  'Bagous (Bagous) diglyptus': ['Coleoptera',
#   'Curculionidae',
#   'Bagous (Bagous)'],
#  'Bagous (Bagous) frit': ['Coleoptera', 'Curculionidae', 'Bagous (Bagous)'],
#  'Bagous (Bagous) limosus': ['Coleoptera', 'Curculionidae', 'Bagous (Bagous)'],
#  'Bagous (Bagous) longitarsis': ['Coleoptera',
#   'Curculionidae',
#   'Bagous (Bagous)'],
#  'Bagous (Bagous) lutulosus': ['Coleoptera',
#   'Curculionidae',
#   'Bagous (Bagous)'],
#  'Bagous (Bagous) nodulosus': ['Coleoptera',
#   'Curculionidae',
#   'Bagous (Bagous)'],
#  'Bagous (Bagous) subcarinatus': ['Coleoptera',
#   'Curculionidae',
#   'Bagous (Bagous)'],
#  'Bagous (Bagous) tempestivus': ['Coleoptera',
#   'Curculionidae',
#   'Bagous (Bagous)'],
#  'Bagous (Cyprus) tubulus': ['Coleoptera', 'Curculionidae', 'Bagous (Cyprus)'],
#  'Bagous (Ephimeropus) petro': ['Coleoptera',
#   'Curculionidae',
#   'Bagous (Ephimeropus)'],
#  'Bagous (Hydronomus) alismatis': ['Coleoptera',
#   'Curculionidae',
#   'Bagous (Hydronomus)'],
#  'Balea (Alinda) biplicata': ['Gastropoda', 'Clausiliidae', 'Balea (Alinda)'],
#  'Ballistura borealis': ['Collembola', 'Isotomidae', 'Ballistura'],
#  'Ballistura schoetti': ['Collembola', 'Isotomidae', 'Ballistura'],
#  'Bandakia concreta': ['Hydracarina', 'Anisitsiellidae', 'Bandakia'],
#  'Barbaxonella angulata': ['Hydracarina', 'Aturidae', 'Barbaxonella'],
#  'Bathynella natans': ['Bathynellacea', 'unspecified', 'Bathynella'],
#  'Bathyomphalus contortus': ['Gastropoda', 'Planorbidae', 'Bathyomphalus'],
#  'Bathythrix argentata': ['Hymenoptera', 'Ichneumonidae', 'Bathythrix'],
#  'Bazarella neglecta': ['Diptera', 'Psychodidae', 'Bazarella'],
#  'Bdellocephala punctata': ['Tricladida', 'Dendrocoelidae', 'Bdellocephala'],
#  'Beauchampia crucigera': ['Rotifera', 'Flosculariidae', 'Beauchampia'],
#  'Beauchampiella eudactylota': ['Rotifera', 'Euchlanidae', 'Beauchampiella'],
#  'Beraea maurus': ['Trichoptera', 'Beraeidae', 'Beraea'],
#  'Beraea pullata': ['Trichoptera', 'Beraeidae', 'Beraea'],
#  'Beraeodes minutus': ['Trichoptera', 'Beraeidae', 'Beraeodes'],
#  'Beris clavipes': ['Diptera', 'Stratiomyidae', 'Beris'],
#  'Beris fuscipes': ['Diptera', 'Stratiomyidae', 'Beris'],
#  'Beris vallata': ['Diptera', 'Stratiomyidae', 'Beris'],
#  'Berosus (Berosus) affinis': ['Coleoptera',
#   'Hydrophilidae',
#   'Berosus (Berosus)'],
#  'Berosus (Berosus) luridus': ['Coleoptera',
#   'Hydrophilidae',
#   'Berosus (Berosus)'],
#  'Berosus (Berosus) signaticollis': ['Coleoptera',
#   'Hydrophilidae',
#   'Berosus (Berosus)'],
#  'Berosus (Enoplurus) fulvus': ['Coleoptera',
#   'Hydrophilidae',
#   'Berosus (Enoplurus)'],
#  'Bezzia (Bezzia) coracina': ['Diptera', 'Ceratopogonidae', 'Bezzia (Bezzia)'],
#  'Bezzia (Bezzia) decincta': ['Diptera', 'Ceratopogonidae', 'Bezzia (Bezzia)'],
#  'Bezzia (Bezzia) flavicornis': ['Diptera',
#   'Ceratopogonidae',
#   'Bezzia (Bezzia)'],
#  'Bezzia (Bezzia) nigritula': ['Diptera',
#   'Ceratopogonidae',
#   'Bezzia (Bezzia)'],
#  'Bezzia (Bezzia) nobilis': ['Diptera', 'Ceratopogonidae', 'Bezzia (Bezzia)'],
#  'Bezzia (Bezzia) ornata': ['Diptera', 'Ceratopogonidae', 'Bezzia (Bezzia)'],
#  'Bezzia (Bezzia) pygmaea': ['Diptera', 'Ceratopogonidae', 'Bezzia (Bezzia)'],
#  'Bezzia (Bezzia) winnertziana': ['Diptera',
#   'Ceratopogonidae',
#   'Bezzia (Bezzia)'],
#  'Bezzia (Homobezzia) annulipes': ['Diptera',
#   'Ceratopogonidae',
#   'Bezzia (Homobezzia)'],
#  'Bezzia (Homobezzia) bicolor': ['Diptera',
#   'Ceratopogonidae',
#   'Bezzia (Homobezzia)'],
#  'Bezzia (Homobezzia) circumdata': ['Diptera',
#   'Ceratopogonidae',
#   'Bezzia (Homobezzia)'],
#  'Bezzia (Homobezzia) fascispinosa': ['Diptera',
#   'Ceratopogonidae',
#   'Bezzia (Homobezzia)'],
#  'Bezzia (Homobezzia) leucogaster': ['Diptera',
#   'Ceratopogonidae',
#   'Bezzia (Homobezzia)'],
#  'Bezzia (Homobezzia) multiannulata': ['Diptera',
#   'Ceratopogonidae',
#   'Bezzia (Homobezzia)'],
#  'Bezzia (Homobezzia) taeniata': ['Diptera',
#   'Ceratopogonidae',
#   'Bezzia (Homobezzia)'],
#  'Bezzia (Pygobezzia) calceata': ['Diptera',
#   'Ceratopogonidae',
#   'Bezzia (Pygobezzia)'],
#  'Bidessus minutissimus': ['Coleoptera', 'Dytiscidae', 'Bidessus'],
#  'Bidessus unistriatus': ['Coleoptera', 'Dytiscidae', 'Bidessus'],
#  'Bithynia (Bithynia) tentaculata': ['Gastropoda',
#   'Bithyniidae',
#   'Bithynia (Bithynia)'],
#  'Bithynia (Codiella) leachii': ['Gastropoda',
#   'Bithyniidae',
#   'Bithynia (Codiella)'],
#  'Boreoclytocerus dalii': ['Diptera', 'Psychodidae', 'Boreoclytocerus'],
#  'Boreoclytocerus ocellaris': ['Diptera', 'Psychodidae', 'Boreoclytocerus'],
#  'Boreoclytocerus rivosus': ['Diptera', 'Psychodidae', 'Boreoclytocerus'],
#  'Bosmina  coregoni': ['Cladocera', 'Bosminidae', 'Bosmina '],
#  'Bosmina  longirostris': ['Cladocera', 'Bosminidae', 'Bosmina '],
#  'Bosmina  longispina': ['Cladocera', 'Bosminidae', 'Bosmina '],
#  'Bothrioneurum vejdovskyanum': ['Oligochaeta',
#   'Tubificidae',
#   'Bothrioneurum'],
#  'Bothrioplana semperi': ['Microturbellaria',
#   'Bothrioplanidae',
#   'Bothrioplana'],
#  'Bothromesostoma personatum': ['Microturbellaria',
#   'Typhloplanidae',
#   'Bothromesostoma'],
#  'Brachionus angularis': ['Rotifera', 'Brachionidae', 'Brachionus'],
#  'Brachionus calyciflorus': ['Rotifera', 'Brachionidae', 'Brachionus'],
#  'Brachionus leydigi': ['Rotifera', 'Brachionidae', 'Brachionus'],
#  'Brachionus patulus': ['Rotifera', 'Brachionidae', 'Brachionus'],
#  'Brachionus plicatilis': ['Rotifera', 'Brachionidae', 'Brachionus'],
#  'Brachionus quadridentatus': ['Rotifera', 'Brachionidae', 'Brachionus'],
#  'Brachionus urceolaris': ['Rotifera', 'Brachionidae', 'Brachionus'],
#  'Brachycentrus subnubilus': ['Trichoptera',
#   'Brachycentridae',
#   'Brachycentrus'],
#  'Brachycercus harrisellus': ['Ephemeroptera', 'Caenidae', 'Brachycercus'],
#  'Brachypoda (Brachypoda) versicolor': ['Hydracarina',
#   'Aturidae',
#   'Brachypoda (Brachypoda)'],
#  'Brachypoda (Ocybrachypoda) celeripes': ['Hydracarina',
#   'Aturidae',
#   'Brachypoda (Ocybrachypoda)'],
#  'Brachypogon (Isohelea) nitidula': ['Diptera',
#   'Ceratopogonidae',
#   'Brachypogon (Isohelea)'],
#  'Brachypogon (Isohelea) perpusilla': ['Diptera',
#   'Ceratopogonidae',
#   'Brachypogon (Isohelea)'],
#  'Brachypogon (Isohelea) sociabilis': ['Diptera',
#   'Ceratopogonidae',
#   'Brachypogon (Isohelea)'],
#  'Brachyptera putata': ['Plecoptera', 'Taeniopterygidae', 'Brachyptera'],
#  'Brachyptera risi': ['Plecoptera', 'Taeniopterygidae', 'Brachyptera'],
#  'Brachytron pratense': ['Odonata', 'Aeshnidae', 'Brachytron'],
#  'Bradleycypris affinis': ['Ostracoda', 'Cyprididae', 'Bradleycypris'],
#  'Bradleycypris fuscatus': ['Ostracoda', 'Cyprididae', 'Bradleycypris'],
#  'Bradleycypris hirsutus': ['Ostracoda', 'Cyprididae', 'Bradleycypris'],
#  'Bradleycypris obliquus': ['Ostracoda', 'Cyprididae', 'Bradleycypris'],
#  'Bradyscela clauda': ['Rotifera', 'Adinetidae', 'Bradyscela'],
#  'Branchiobdella astaci': ['Branchiobdellida',
#   'unspecified',
#   'Branchiobdella'],
#  'Branchiura sowerbyi': ['Oligochaeta', 'Tubificidae', 'Branchiura'],
#  'Brillia bifida': ['Diptera', 'Orthocladiinae', 'Brillia'],
#  'Brillia flavifrons': ['Diptera', 'Orthocladiinae', 'Brillia'],
#  'Bryceella stylata': ['Rotifera', 'Proalidae', 'Bryceella'],
#  'Bryceella tenella': ['Rotifera', 'Proalidae', 'Bryceella'],
#  'Brychius elevatus': ['Coleoptera', 'Haliplidae', 'Brychius'],
#  'Bryocamptus (Arcticocamptus) cuspidatus': ['Copepoda',
#   'Canthocamptidae',
#   'Bryocamptus (Arcticocamptus)'],
#  'Bryocamptus (Arcticocamptus) rhaeticus': ['Copepoda',
#   'Canthocamptidae',
#   'Bryocamptus (Arcticocamptus)'],
#  'Bryocamptus (Bryocamptus) minutus': ['Copepoda',
#   'Canthocamptidae',
#   'Bryocamptus (Bryocamptus)'],
#  'Bryocamptus (Limnocamptus) echinatus': ['Copepoda',
#   'Canthocamptidae',
#   'Bryocamptus (Limnocamptus)'],
#  'Bryocamptus (Limnocamptus) praegeri': ['Copepoda',
#   'Canthocamptidae',
#   'Bryocamptus (Limnocamptus)'],
#  'Bryocamptus (Rheocamptus) pygmaeus': ['Copepoda',
#   'Canthocamptidae',
#   'Bryocamptus (Rheocamptus)'],
#  'Bryocamptus (Rheocamptus) typhlops': ['Copepoda',
#   'Canthocamptidae',
#   'Bryocamptus (Rheocamptus)'],
#  'Bryocamptus (Rheocamptus) weberi': ['Copepoda',
#   'Canthocamptidae',
#   'Bryocamptus (Rheocamptus)'],
#  'Bryocamptus (Rheocamptus) zschokkei': ['Copepoda',
#   'Canthocamptidae',
#   'Bryocamptus (Rheocamptus)'],
#  'Bryophaenocladius aestivus': ['Diptera',
#   'Orthocladiinae',
#   'Bryophaenocladius'],
#  'Bryophaenocladius femineus': ['Diptera',
#   'Orthocladiinae',
#   'Bryophaenocladius'],
#  'Bryophaenocladius flexidens': ['Diptera',
#   'Orthocladiinae',
#   'Bryophaenocladius'],
#  'Bryophaenocladius furcatus': ['Diptera',
#   'Orthocladiinae',
#   'Bryophaenocladius'],
#  'Bryophaenocladius ictericus': ['Diptera',
#   'Orthocladiinae',
#   'Bryophaenocladius'],
#  'Bryophaenocladius illimbatus': ['Diptera',
#   'Orthocladiinae',
#   'Bryophaenocladius'],
#  'Bryophaenocladius inconstans': ['Diptera',
#   'Orthocladiinae',
#   'Bryophaenocladius'],
#  'Bryophaenocladius muscicola': ['Diptera',
#   'Orthocladiinae',
#   'Bryophaenocladius'],
#  'Bryophaenocladius nidorum': ['Diptera',
#   'Orthocladiinae',
#   'Bryophaenocladius'],
#  'Bryophaenocladius nitidicollis': ['Diptera',
#   'Orthocladiinae',
#   'Bryophaenocladius'],
#  'Bryophaenocladius simus': ['Diptera', 'Orthocladiinae', 'Bryophaenocladius'],
#  'Bryophaenocladius subvernalis': ['Diptera',
#   'Orthocladiinae',
#   'Bryophaenocladius'],
#  'Bryophaenocladius tuberculatus': ['Diptera',
#   'Orthocladiinae',
#   'Bryophaenocladius'],
#  'Bryophaenocladius vernalis': ['Diptera',
#   'Orthocladiinae',
#   'Bryophaenocladius'],
#  'Bryophaenocladius xanthogyne': ['Diptera',
#   'Orthocladiinae',
#   'Bryophaenocladius'],
#  'Buchholzia fallax': ['Oligochaeta', 'Enchytraeidae', 'Buchholzia'],
#  'Buchonomyia thienemanni': ['Diptera', 'Buchonomyiinae', 'Buchonomyia'],
#  'Bythonomus lemani': ['Oligochaeta', 'Lumbriculidae', 'Bythonomus'],
#  'Bythotrephes  longimanus': ['Cladocera', 'Cercopagidae', 'Bythotrephes '],
#  'Caecidotea communis': ['Isopoda', 'Asellidae', 'Caecidotea'],
#  'Caenis beskidensis': ['Ephemeroptera', 'Caenidae', 'Caenis'],
#  'Caenis horaria': ['Ephemeroptera', 'Caenidae', 'Caenis'],
#  'Caenis luctuosa': ['Ephemeroptera', 'Caenidae', 'Caenis'],
#  'Caenis macrura': ['Ephemeroptera', 'Caenidae', 'Caenis'],
#  'Caenis pseudorivulorum': ['Ephemeroptera', 'Caenidae', 'Caenis'],
#  'Caenis pusilla': ['Ephemeroptera', 'Caenidae', 'Caenis'],
#  'Caenis rivulorum': ['Ephemeroptera', 'Caenidae', 'Caenis'],
#  'Caenis robusta': ['Ephemeroptera', 'Caenidae', 'Caenis'],
#  'Caligus pageti': ['Copepoda', 'Caligidae', 'Caligus'],
#  'Callicorixa praeusta': ['Hemiptera', 'Corixidae', 'Callicorixa'],
#  'Callicorixa wollastoni': ['Hemiptera', 'Corixidae', 'Callicorixa'],
#  'Calopteryx splendens': ['Odonata', 'Calopterygidae', 'Calopteryx'],
#  'Calopteryx virgo': ['Odonata', 'Calopterygidae', 'Calopteryx'],
#  'Campsicnemus armatus': ['Diptera', 'Dolichopodidae', 'Campsicnemus'],
#  'Campsicnemus compeditus': ['Diptera', 'Dolichopodidae', 'Campsicnemus'],
#  'Campsicnemus curvipes': ['Diptera', 'Dolichopodidae', 'Campsicnemus'],
#  'Campsicnemus dasycnemus': ['Diptera', 'Dolichopodidae', 'Campsicnemus'],
#  'Campsicnemus loripes': ['Diptera', 'Dolichopodidae', 'Campsicnemus'],
#  'Campsicnemus magius': ['Diptera', 'Dolichopodidae', 'Campsicnemus'],
#  'Campsicnemus marginatus': ['Diptera', 'Dolichopodidae', 'Campsicnemus'],
#  'Campsicnemus picticornis': ['Diptera', 'Dolichopodidae', 'Campsicnemus'],
#  'Campsicnemus pumilio': ['Diptera', 'Dolichopodidae', 'Campsicnemus'],
#  'Campsicnemus pusillus': ['Diptera', 'Dolichopodidae', 'Campsicnemus'],
#  'Campsicnemus scambus': ['Diptera', 'Dolichopodidae', 'Campsicnemus'],
#  'Campsicnemus umbripennis': ['Diptera', 'Dolichopodidae', 'Campsicnemus'],
#  'Camptocercus  lilljeborgi': ['Cladocera', 'Chydoridae', 'Camptocercus '],
#  'Camptocercus  rectirostris': ['Cladocera', 'Chydoridae', 'Camptocercus '],
#  'Camptocladius stercorarius': ['Diptera', 'Orthocladiinae', 'Camptocladius'],
#  'Candona (Candona) angulata': ['Ostracoda',
#   'Candonidae',
#   'Candona (Candona)'],
#  'Candona (Candona) candida': ['Ostracoda', 'Candonidae', 'Candona (Candona)'],
#  'Candona (Candona) neglecta': ['Ostracoda',
#   'Candonidae',
#   'Candona (Candona)'],
#  'Candona (Candona) weltneri': ['Ostracoda',
#   'Candonidae',
#   'Candona (Candona)'],
#  'Candona (Cryptocandona) reducta': ['Ostracoda',
#   'Candonidae',
#   'Candona (Cryptocandona)'],
#  'Candona (Cryptocandona) vavrai': ['Ostracoda',
#   'Candonidae',
#   'Candona (Cryptocandona)'],
#  'Candona (Eucandona) acuminata': ['Ostracoda',
#   'Candonidae',
#   'Candona (Eucandona)'],
#  'Candona (Eucandona) caudata': ['Ostracoda',
#   'Candonidae',
#   'Candona (Eucandona)'],
#  'Candona (Eucandona) hyalina': ['Ostracoda',
#   'Candonidae',
#   'Candona (Eucandona)'],
#  'Candona (Eucandona) protzi': ['Ostracoda',
#   'Candonidae',
#   'Candona (Eucandona)'],
#  'Candona (Fabaeformiscandona) fabaeformis': ['Ostracoda',
#   'Candonidae',
#   'Candona (Fabaeformiscandona)'],
#  'Candona (Typhlocypris) compressa': ['Ostracoda',
#   'Candonidae',
#   'Candona (Typhlocypris)'],
#  'Candona (Typhlocypris) insculpta': ['Ostracoda',
#   'Candonidae',
#   'Candona (Typhlocypris)'],
#  'Candona (Typhlocypris) lobipes': ['Ostracoda',
#   'Candonidae',
#   'Candona (Typhlocypris)'],
#  'Candona (Typhlocypris) marchica': ['Ostracoda',
#   'Candonidae',
#   'Candona (Typhlocypris)'],
#  'Candona (Typhlocypris) parallela': ['Ostracoda',
#   'Candonidae',
#   'Candona (Typhlocypris)'],
#  'Candona (Typhlocypris) pratensis': ['Ostracoda',
#   'Candonidae',
#   'Candona (Typhlocypris)'],
#  'Candona (Typhlocypris) rostrata': ['Ostracoda',
#   'Candonidae',
#   'Candona (Typhlocypris)'],
#  'Candona (Typhlocypris) sarsi': ['Ostracoda',
#   'Candonidae',
#   'Candona (Typhlocypris)'],
#  'Candona (Typhlocypris) stagnalis': ['Ostracoda',
#   'Candonidae',
#   'Candona (Typhlocypris)'],
#  'Candonopsis kingsleii': ['Ostracoda', 'Candonidae', 'Candonopsis'],
#  'Canthocamptus microstaphylinus': ['Copepoda',
#   'Canthocamptidae',
#   'Canthocamptus'],
#  'Canthocamptus staphylinus': ['Copepoda', 'Canthocamptidae', 'Canthocamptus'],
#  'Capnia atra': ['Plecoptera', 'Capniidae', 'Capnia'],
#  'Capnia bifrons': ['Plecoptera', 'Capniidae', 'Capnia'],
#  'Capnia vidua': ['Plecoptera', 'Capniidae', 'Capnia'],
#  'Caraphractus cinctus': ['Hymenoptera', 'Mymaridae', 'Caraphractus'],
#  'Cardiocladius capucinus': ['Diptera', 'Orthocladiinae', 'Cardiocladius'],
#  'Cardiocladius fuscus': ['Diptera', 'Orthocladiinae', 'Cardiocladius'],
#  'Carychium minimum': ['Gastropoda', 'Carychiidae', 'Carychium'],
#  'Castrada armata': ['Microturbellaria', 'Typhloplanidae', 'Castrada'],
#  'Castrada lanceola': ['Microturbellaria', 'Typhloplanidae', 'Castrada'],
#  'Castrada luteola': ['Microturbellaria', 'Typhloplanidae', 'Castrada'],
#  'Castrada neocomensis': ['Microturbellaria', 'Typhloplanidae', 'Castrada'],
#  'Castrada viridis': ['Microturbellaria', 'Typhloplanidae', 'Castrada'],
#  'Castrella truncata': ['Microturbellaria', 'Dalyelliidae', 'Castrella'],
#  'Cataclysta lemnata': ['Lepidoptera', 'Pyralidae', 'Cataclysta'],
#  'Catenula lemnae': ['Microturbellaria', 'Catenulidae', 'Catenula'],
#  'Cavernocypris subterranea': ['Ostracoda', 'Darwinulidae', 'Cavernocypris'],
#  'Centropages hamatus': ['Copepoda', 'Centropagidae', 'Centropages'],
#  'Centroptilum luteolum': ['Ephemeroptera', 'Baetidae', 'Centroptilum'],
#  'Cephalobus persegnis': ['Nematoda', 'Cephalobidae', 'Cephalobus'],
#  'Cephalodella auriculata': ['Rotifera', 'Notommatidae', 'Cephalodella'],
#  'Cephalodella biungulata': ['Rotifera', 'Notommatidae', 'Cephalodella'],
#  'Cephalodella catellina': ['Rotifera', 'Notommatidae', 'Cephalodella'],
#  'Cephalodella crassipes': ['Rotifera', 'Notommatidae', 'Cephalodella'],
#  'Cephalodella derbyi': ['Rotifera', 'Notommatidae', 'Cephalodella'],
#  'Cephalodella eva': ['Rotifera', 'Notommatidae', 'Cephalodella'],
#  'Cephalodella exigua': ['Rotifera', 'Notommatidae', 'Cephalodella'],
#  'Cephalodella forficata': ['Rotifera', 'Notommatidae', 'Cephalodella'],
#  'Cephalodella forficula': ['Rotifera', 'Notommatidae', 'Cephalodella'],
#  'Cephalodella gibba': ['Rotifera', 'Notommatidae', 'Cephalodella'],
#  'Cephalodella globata': ['Rotifera', 'Notommatidae', 'Cephalodella'],
#  'Cephalodella gracilis': ['Rotifera', 'Notommatidae', 'Cephalodella'],
#  'Cephalodella hoodi': ['Rotifera', 'Notommatidae', 'Cephalodella'],
#  'Cephalodella megalocephala': ['Rotifera', 'Notommatidae', 'Cephalodella'],
#  'Cephalodella obvia': ['Rotifera', 'Notommatidae', 'Cephalodella'],
#  'Cephalodella sterea': ['Rotifera', 'Notommatidae', 'Cephalodella'],
#  'Cephalodella strigosa': ['Rotifera', 'Notommatidae', 'Cephalodella'],
#  'Cephalodella tenuior': ['Rotifera', 'Notommatidae', 'Cephalodella'],
#  'Cephalodella tenuiseta': ['Rotifera', 'Notommatidae', 'Cephalodella'],
#  'Cephalodella ventripes': ['Rotifera', 'Notommatidae', 'Cephalodella'],
#  'Ceraclea albimacula': ['Trichoptera', 'Leptoceridae', 'Ceraclea'],
#  'Ceraclea annulicornis': ['Trichoptera', 'Leptoceridae', 'Ceraclea'],
#  'Ceraclea dissimilis': ['Trichoptera', 'Leptoceridae', 'Ceraclea'],
#  'Ceraclea fulva': ['Trichoptera', 'Leptoceridae', 'Ceraclea'],
#  'Ceraclea nigronervosa': ['Trichoptera', 'Leptoceridae', 'Ceraclea'],
#  'Ceraclea senilis': ['Trichoptera', 'Leptoceridae', 'Ceraclea'],
#  'Ceratopogon communis': ['Diptera', 'Ceratopogonidae', 'Ceratopogon'],
#  'Ceratopogon denticulatus': ['Diptera', 'Ceratopogonidae', 'Ceratopogon'],
#  'Ceratopogon grandiforceps': ['Diptera', 'Ceratopogonidae', 'Ceratopogon'],
#  'Ceratopogon lacteipennis': ['Diptera', 'Ceratopogonidae', 'Ceratopogon'],
#  'Ceratopogon niveipennis': ['Diptera', 'Ceratopogonidae', 'Ceratopogon'],
#  'Ceratotrocha cornigera': ['Rotifera', 'Philodinidae', 'Ceratotrocha'],
#  'Ceratozetes furcatus': ['Oribatei', 'Ceratozetidae', 'Ceratozetes'],
#  'Cercyon (Cercyon) alpinus': ['Coleoptera',
#   'Hydrophilidae',
#   'Cercyon (Cercyon)'],
#  'Cercyon (Cercyon) bifenestratus': ['Coleoptera',
#   'Hydrophilidae',
#   'Cercyon (Cercyon)'],
#  'Cercyon (Cercyon) convexiusculus': ['Coleoptera',
#   'Hydrophilidae',
#   'Cercyon (Cercyon)'],
#  'Cercyon (Cercyon) depressus': ['Coleoptera',
#   'Hydrophilidae',
#   'Cercyon (Cercyon)'],
#  'Cercyon (Cercyon) granarius': ['Coleoptera',
#   'Hydrophilidae',
#   'Cercyon (Cercyon)'],
#  'Cercyon (Cercyon) haemorrhoidalis': ['Coleoptera',
#   'Hydrophilidae',
#   'Cercyon (Cercyon)'],
#  'Cercyon (Cercyon) impressus': ['Coleoptera',
#   'Hydrophilidae',
#   'Cercyon (Cercyon)'],
#  'Cercyon (Cercyon) laminatus': ['Coleoptera',
#   'Hydrophilidae',
#   'Cercyon (Cercyon)'],
#  'Cercyon (Cercyon) lateralis': ['Coleoptera',
#   'Hydrophilidae',
#   'Cercyon (Cercyon)'],
#  'Cercyon (Cercyon) littoralis': ['Coleoptera',
#   'Hydrophilidae',
#   'Cercyon (Cercyon)'],
#  'Cercyon (Cercyon) marinus': ['Coleoptera',
#   'Hydrophilidae',
#   'Cercyon (Cercyon)'],
#  'Cercyon (Cercyon) melanocephalus': ['Coleoptera',
#   'Hydrophilidae',
#   'Cercyon (Cercyon)'],
#  'Cercyon (Cercyon) nigriceps': ['Coleoptera',
#   'Hydrophilidae',
#   'Cercyon (Cercyon)'],
#  'Cercyon (Cercyon) obsoletus': ['Coleoptera',
#   'Hydrophilidae',
#   'Cercyon (Cercyon)'],
#  'Cercyon (Cercyon) pygmaeus': ['Coleoptera',
#   'Hydrophilidae',
#   'Cercyon (Cercyon)'],
#  'Cercyon (Cercyon) quisquilius': ['Coleoptera',
#   'Hydrophilidae',
#   'Cercyon (Cercyon)'],
#  'Cercyon (Cercyon) sternalis': ['Coleoptera',
#   'Hydrophilidae',
#   'Cercyon (Cercyon)'],
#  'Cercyon (Cercyon) terminatus': ['Coleoptera',
#   'Hydrophilidae',
#   'Cercyon (Cercyon)'],
#  'Cercyon (Cercyon) tristis': ['Coleoptera',
#   'Hydrophilidae',
#   'Cercyon (Cercyon)'],
#  'Cercyon (Cercyon) unipunctatus': ['Coleoptera',
#   'Hydrophilidae',
#   'Cercyon (Cercyon)'],
#  'Cercyon (Dicyrtocercyon) ustulatus': ['Coleoptera',
#   'Hydrophilidae',
#   'Cercyon (Dicyrtocercyon)'],
#  'Cercyon (Paracercyon) analis': ['Coleoptera',
#   'Hydrophilidae',
#   'Cercyon (Paracercyon)'],
#  'Ceriagrion tenellum': ['Odonata', 'Coenagrionidae', 'Ceriagrion'],
#  'Ceriodaphnia  dubia': ['Cladocera', 'Daphniidae', 'Ceriodaphnia '],
#  'Ceriodaphnia  laticaudata': ['Cladocera', 'Daphniidae', 'Ceriodaphnia '],
#  'Ceriodaphnia  megops': ['Cladocera', 'Daphniidae', 'Ceriodaphnia '],
#  'Ceriodaphnia  pulchella': ['Cladocera', 'Daphniidae', 'Ceriodaphnia '],
#  'Ceriodaphnia  quadrangula': ['Cladocera', 'Daphniidae', 'Ceriodaphnia '],
#  'Ceriodaphnia  reticulata': ['Cladocera', 'Daphniidae', 'Ceriodaphnia '],
#  'Ceriodaphnia  setosa': ['Cladocera', 'Daphniidae', 'Ceriodaphnia '],
#  'Cernosvitoviella atrata': ['Oligochaeta',
#   'Enchytraeidae',
#   'Cernosvitoviella'],
#  'Cernosvitoviella immota': ['Oligochaeta',
#   'Enchytraeidae',
#   'Cernosvitoviella'],
#  'Chaenusa conjugens': ['Hymenoptera', 'Braconidae', 'Chaenusa'],
#  'Chaenusa limoniadum': ['Hymenoptera', 'Braconidae', 'Chaenusa'],
#  'Chaenusa naiadum': ['Hymenoptera', 'Braconidae', 'Chaenusa'],
#  'Chaenusa nereidum': ['Hymenoptera', 'Braconidae', 'Chaenusa'],
#  'Chaetarthria seminulum': ['Coleoptera', 'Hydrophilidae', 'Chaetarthria'],
#  'Chaetarthria simillima': ['Coleoptera', 'Hydrophilidae', 'Chaetarthria'],
#  'Chaetocladius dentiforceps': ['Diptera', 'Orthocladiinae', 'Chaetocladius'],
#  'Chaetocladius dissipatus': ['Diptera', 'Orthocladiinae', 'Chaetocladius'],
#  'Chaetocladius insolitus': ['Diptera', 'Orthocladiinae', 'Chaetocladius'],
#  'Chaetocladius melaleucus': ['Diptera', 'Orthocladiinae', 'Chaetocladius'],
# ...
#  'Tipula (Platytipula) luteipennis': ['Diptera',
#   'Tipulidae',
#   'Tipula (Platytipula)'],
#  'Tipula (Platytipula) melanoceros': ['Diptera',
#   'Tipulidae',
#   'Tipula (Platytipula)'],
#  'Tipula (Pterelachisus) pabulina': ['Diptera',
#   'Tipulidae',
#   'Tipula (Pterelachisus)'],
#  'Tipula (Pterelachisus) truncorum': ['Diptera',
#   'Tipulidae',
#   'Tipula (Pterelachisus)'],
#  'Tipula (Savtshenkia) alpium': ['Diptera',
#   'Tipulidae',
#   'Tipula (Savtshenkia)'],
#  'Tipula (Savtshenkia) cheethami': ['Diptera',
#   'Tipulidae',
#   'Tipula (Savtshenkia)'],
#  'Tipula (Savtshenkia) confusa': ['Diptera',
#   'Tipulidae',
#   'Tipula (Savtshenkia)'],
#  'Tipula (Savtshenkia) gimmerthali': ['Diptera',
#   'Tipulidae',
#   'Tipula (Savtshenkia)'],
#  'Tipula (Savtshenkia) grisescens': ['Diptera',
#   'Tipulidae',
#   'Tipula (Savtshenkia)'],
#  'Tipula (Savtshenkia) limbata': ['Diptera',
#   'Tipulidae',
#   'Tipula (Savtshenkia)'],
#  'Tipula (Savtshenkia) obsoleta': ['Diptera',
#   'Tipulidae',
#   'Tipula (Savtshenkia)'],
#  'Tipula (Savtshenkia) pagana': ['Diptera',
#   'Tipulidae',
#   'Tipula (Savtshenkia)'],
#  'Tipula (Savtshenkia) rufina': ['Diptera',
#   'Tipulidae',
#   'Tipula (Savtshenkia)'],
#  'Tipula (Savtshenkia) serrulifera': ['Diptera',
#   'Tipulidae',
#   'Tipula (Savtshenkia)'],
#  'Tipula (Savtshenkia) signata': ['Diptera',
#   'Tipulidae',
#   'Tipula (Savtshenkia)'],
#  'Tipula (Savtshenkia) staegeri': ['Diptera',
#   'Tipulidae',
#   'Tipula (Savtshenkia)'],
#  'Tipula (Savtshenkia) subnodicornis': ['Diptera',
#   'Tipulidae',
#   'Tipula (Savtshenkia)'],
#  'Tipula (Schummelia) variicornis': ['Diptera',
#   'Tipulidae',
#   'Tipula (Schummelia)'],
#  'Tipula (Schummelia) yerburyi': ['Diptera',
#   'Tipulidae',
#   'Tipula (Schummelia)'],
#  'Tipula (Tipula) oleracea': ['Diptera', 'Tipulidae', 'Tipula (Tipula)'],
#  'Tipula (Tipula) paludosa': ['Diptera', 'Tipulidae', 'Tipula (Tipula)'],
#  'Tipula (Tipula) subcunctans': ['Diptera', 'Tipulidae', 'Tipula (Tipula)'],
#  'Tipula (Yamatotipula) coerulescens': ['Diptera',
#   'Tipulidae',
#   'Tipula (Yamatotipula)'],
#  'Tipula (Yamatotipula) couckei': ['Diptera',
#   'Tipulidae',
#   'Tipula (Yamatotipula)'],
#  'Tipula (Yamatotipula) lateralis': ['Diptera',
#   'Tipulidae',
#   'Tipula (Yamatotipula)'],
#  'Tipula (Yamatotipula) marginella': ['Diptera',
#   'Tipulidae',
#   'Tipula (Yamatotipula)'],
#  'Tipula (Yamatotipula) montium': ['Diptera',
#   'Tipulidae',
#   'Tipula (Yamatotipula)'],
#  'Tipula (Yamatotipula) pierrei': ['Diptera',
#   'Tipulidae',
#   'Tipula (Yamatotipula)'],
#  'Tipula (Yamatotipula) pruinosa': ['Diptera',
#   'Tipulidae',
#   'Tipula (Yamatotipula)'],
#  'Tobrilus gracilis': ['Nematoda', 'Tripylidae', 'Tobrilus'],
#  'Tobrilus pellucidus': ['Nematoda', 'Tripylidae', 'Tobrilus'],
#  'Tokunagaia tonolli': ['Diptera', 'Orthocladiinae', 'Tokunagaia'],
#  'Tonnoiriella anchoriformis': ['Diptera', 'Psychodidae', 'Tonnoiriella'],
#  'Tonnoiriella nigricauda': ['Diptera', 'Psychodidae', 'Tonnoiriella'],
#  'Tonnoiriella pulchra': ['Diptera', 'Psychodidae', 'Tonnoiriella'],
#  'Torrenticola (Monatractides) madritensis': ['Hydracarina',
#   'Torrenticolidae',
#   'Torrenticola (Monatractides)'],
#  'Torrenticola (Torrenticola) amplexa': ['Hydracarina',
#   'Torrenticolidae',
#   'Torrenticola (Torrenticola)'],
#  'Torrenticola (Torrenticola) andrei': ['Hydracarina',
#   'Torrenticolidae',
#   'Torrenticola (Torrenticola)'],
#  'Torrenticola (Torrenticola) anomala': ['Hydracarina',
#   'Torrenticolidae',
#   'Torrenticola (Torrenticola)'],
#  'Torrenticola (Torrenticola) brevirostris': ['Hydracarina',
#   'Torrenticolidae',
#   'Torrenticola (Torrenticola)'],
#  'Torrenticola (Torrenticola) elliptica': ['Hydracarina',
#   'Torrenticolidae',
#   'Torrenticola (Torrenticola)'],
#  'Torrenticola (Torrenticola) halberti': ['Hydracarina',
#   'Torrenticolidae',
#   'Torrenticola (Torrenticola)'],
#  'Torrenticola (Torrenticola) maglioi': ['Hydracarina',
#   'Torrenticolidae',
#   'Torrenticola (Torrenticola)'],
#  'Torrenticola (Torrenticola) parvipalpis': ['Hydracarina',
#   'Torrenticolidae',
#   'Torrenticola (Torrenticola)'],
#  'Torrenticola (Torrenticola) robusta': ['Hydracarina',
#   'Torrenticolidae',
#   'Torrenticola (Torrenticola)'],
#  'Torrenticola (Torrenticola) thori': ['Hydracarina',
#   'Torrenticolidae',
#   'Torrenticola (Torrenticola)'],
#  'Tournotaris bimaculatus': ['Coleoptera', 'Erirhinidae', 'Tournotaris'],
#  'Tracheliastes maculatus': ['Copepoda', 'Lernaeopodidae', 'Tracheliastes'],
#  'Tracheliastes polycolpus': ['Copepoda', 'Lernaeopodidae', 'Tracheliastes'],
#  'Tretocephala  ambigua': ['Cladocera', 'Chydoridae', 'Tretocephala '],
#  'Triaenodes bicolor': ['Trichoptera', 'Leptoceridae', 'Triaenodes'],
#  'Tribelos intextus': ['Diptera', 'Chironominae (Chironomini)', 'Tribelos'],
#  'Trichia hispida': ['Gastropoda', 'Helicidae', 'Trichia'],
#  'Trichocerca (Diurella) bidens': ['Rotifera',
#   'Trichocercidae',
#   'Trichocerca (Diurella)'],
#  'Trichocerca (Diurella) birostris': ['Rotifera',
#   'Trichocercidae',
#   'Trichocerca (Diurella)'],
#  'Trichocerca (Diurella) brachyura': ['Rotifera',
#   'Trichocercidae',
#   'Trichocerca (Diurella)'],
#  'Trichocerca (Diurella) cavia': ['Rotifera',
#   'Trichocercidae',
#   'Trichocerca (Diurella)'],
#  'Trichocerca (Diurella) collaris': ['Rotifera',
#   'Trichocercidae',
#   'Trichocerca (Diurella)'],
#  'Trichocerca (Diurella) dixon-nuttalli': ['Rotifera',
#   'Trichocercidae',
#   'Trichocerca (Diurella)'],
#  'Trichocerca (Diurella) inermis': ['Rotifera',
#   'Trichocercidae',
#   'Trichocerca (Diurella)'],
#  'Trichocerca (Diurella) intermedia': ['Rotifera',
#   'Trichocercidae',
#   'Trichocerca (Diurella)'],
#  'Trichocerca (Diurella) porcellus': ['Rotifera',
#   'Trichocercidae',
#   'Trichocerca (Diurella)'],
#  'Trichocerca (Diurella) rousseleti': ['Rotifera',
#   'Trichocercidae',
#   'Trichocerca (Diurella)'],
#  'Trichocerca (Diurella) similis': ['Rotifera',
#   'Trichocercidae',
#   'Trichocerca (Diurella)'],
#  'Trichocerca (Diurella) sulcata': ['Rotifera',
#   'Trichocercidae',
#   'Trichocerca (Diurella)'],
#  'Trichocerca (Diurella) tenuior': ['Rotifera',
#   'Trichocercidae',
#   'Trichocerca (Diurella)'],
#  'Trichocerca (Diurella) tigris': ['Rotifera',
#   'Trichocercidae',
#   'Trichocerca (Diurella)'],
#  'Trichocerca (Diurella) weberi': ['Rotifera',
#   'Trichocercidae',
#   'Trichocerca (Diurella)'],
#  'Trichocerca (Trichocerca) bicristata': ['Rotifera',
#   'Trichocercidae',
#   'Trichocerca (Trichocerca)'],
#  'Trichocerca (Trichocerca) capucina': ['Rotifera',
#   'Trichocercidae',
#   'Trichocerca (Trichocerca)'],
#  'Trichocerca (Trichocerca) cylindrica': ['Rotifera',
#   'Trichocercidae',
#   'Trichocerca (Trichocerca)'],
#  'Trichocerca (Trichocerca) elongata': ['Rotifera',
#   'Trichocercidae',
#   'Trichocerca (Trichocerca)'],
#  'Trichocerca (Trichocerca) iernis': ['Rotifera',
#   'Trichocercidae',
#   'Trichocerca (Trichocerca)'],
#  'Trichocerca (Trichocerca) jenningsi': ['Rotifera',
#   'Trichocercidae',
#   'Trichocerca (Trichocerca)'],
#  'Trichocerca (Trichocerca) longiseta': ['Rotifera',
#   'Trichocercidae',
#   'Trichocerca (Trichocerca)'],
#  'Trichocerca (Trichocerca) lophoessa': ['Rotifera',
#   'Trichocercidae',
#   'Trichocerca (Trichocerca)'],
#  'Trichocerca (Trichocerca) macera': ['Rotifera',
#   'Trichocercidae',
#   'Trichocerca (Trichocerca)'],
#  'Trichocerca (Trichocerca) marina': ['Rotifera',
#   'Trichocercidae',
#   'Trichocerca (Trichocerca)'],
#  'Trichocerca (Trichocerca) pusilla': ['Rotifera',
#   'Trichocercidae',
#   'Trichocerca (Trichocerca)'],
#  'Trichocerca (Trichocerca) rattus': ['Rotifera',
#   'Trichocercidae',
#   'Trichocerca (Trichocerca)'],
#  'Trichocerca (Trichocerca) stylata': ['Rotifera',
#   'Trichocercidae',
#   'Trichocerca (Trichocerca)'],
#  'Trichodrilus allobrogum': ['Oligochaeta', 'Lumbriculidae', 'Trichodrilus'],
#  'Trichodrilus cantabrigiensis': ['Oligochaeta',
#   'Lumbriculidae',
#   'Trichodrilus'],
#  'Trichodrilus hrabei': ['Oligochaeta', 'Lumbriculidae', 'Trichodrilus'],
#  'Tricholeiochiton fagesii': ['Trichoptera',
#   'Hydroptilidae',
#   'Tricholeiochiton'],
#  'Trichopalpus fraternus': ['Diptera', 'Scathophagidae', 'Trichopalpus'],
#  'Trichopeza longicornis': ['Diptera', 'Empididae', 'Trichopeza'],
#  'Trichostegia minor': ['Trichoptera', 'Phryganeidae', 'Trichostegia'],
#  'Trichothyas (Lundbladia) petrophila': ['Hydracarina',
#   'Hydryphantidae',
#   'Trichothyas (Lundbladia)'],
#  'Trichotria pocillum': ['Rotifera', 'Trichotridae', 'Trichotria'],
#  'Trichotria tetractis': ['Rotifera', 'Trichotridae', 'Trichotria'],
#  'Trichotria truncata': ['Rotifera', 'Trichotridae', 'Trichotria'],
#  'Tricyphona (Tricyphona) immaculata': ['Diptera',
#   'Pediciidae',
#   'Tricyphona (Tricyphona)'],
#  'Tricyphona (Tricyphona) schummeli': ['Diptera',
#   'Pediciidae',
#   'Tricyphona (Tricyphona)'],
#  'Tricyphona (Tricyphona) unicolor': ['Diptera',
#   'Pediciidae',
#   'Tricyphona (Tricyphona)'],
#  'Trimicra pilipes': ['Diptera', 'Limoniidae', 'Trimicra'],
#  'Triogma trisulcata': ['Diptera', 'Cylindrotomidae', 'Triogma'],
#  'Triops cancriformis': ['Notostraca', 'unspecified', 'Triops'],
#  'Tripleuchlanis plicata': ['Rotifera', 'Euchlanidae', 'Tripleuchlanis'],
#  'Tripyla affinis': ['Nematoda', 'Tripylidae', 'Tripyla'],
#  'Tripyla filicaudata': ['Nematoda', 'Tripylidae', 'Tripyla'],
#  'Tripyla glomerans': ['Nematoda', 'Tripylidae', 'Tripyla'],
#  'Tripyla setifera': ['Nematoda', 'Tripylidae', 'Tripyla'],
#  'Trissocladius brevipalpis': ['Diptera', 'Orthocladiinae', 'Trissocladius'],
#  'Trissopelopia longimana': ['Diptera', 'Tanypodinae', 'Trissopelopia'],
#  'Trocheta bykowskii': ['Hirudinea', 'Erpobdellidae', 'Trocheta'],
#  'Trocheta subviridis': ['Hirudinea', 'Erpobdellidae', 'Trocheta'],
#  'Tropocyclops prasinus': ['Copepoda', 'Cyclopidae', 'Tropocyclops'],
#  'Tubifex costatus': ['Oligochaeta', 'Tubificidae', 'Tubifex'],
#  'Tubifex ignotus': ['Oligochaeta', 'Tubificidae', 'Tubifex'],
#  'Tubifex nerthus': ['Oligochaeta', 'Tubificidae', 'Tubifex'],
#  'Tubifex newaensis': ['Oligochaeta', 'Tubificidae', 'Tubifex'],
#  'Tubifex tubifex': ['Oligochaeta', 'Tubificidae', 'Tubifex'],
#  'Tubificoides benedii': ['Oligochaeta', 'Tubificidae', 'Tubificoides'],
#  'Tubificoides pseudogaster': ['Oligochaeta', 'Tubificidae', 'Tubificoides'],
#  'Tvetenia bavarica': ['Diptera', 'Orthocladiinae', 'Tvetenia'],
#  'Tvetenia calvescens': ['Diptera', 'Orthocladiinae', 'Tvetenia'],
#  'Tvetenia discoloripes': ['Diptera', 'Orthocladiinae', 'Tvetenia'],
#  'Tvetenia verralli': ['Diptera', 'Orthocladiinae', 'Tvetenia'],
#  'Tylencholaimellus fenensis': ['Nematoda',
#   'Leptonchidae',
#   'Tylencholaimellus'],
#  'Tylenchus agricola': ['Nematoda', 'Tylenchidae', 'Tylenchus'],
#  'Tylenchus bryophilus': ['Nematoda', 'Tylenchidae', 'Tylenchus'],
#  'Tylenchus davainei': ['Nematoda', 'Tylenchidae', 'Tylenchus'],
#  'Tylenchus filiformis': ['Nematoda', 'Tylenchidae', 'Tylenchus'],
#  'Typhloplana viridata': ['Microturbellaria', 'Typhloplanidae', 'Typhloplana'],
#  'Uncinais uncinata': ['Oligochaeta', 'Naididae', 'Uncinais'],
#  'Unio pictorum': ['Bivalvia', 'Unionidae', 'Unio'],
#  'Unio tumidus': ['Bivalvia', 'Unionidae', 'Unio'],
#  'Unionicola (Parasitatax) ypsilophora': ['Hydracarina',
#   'Unionicolidae',
#   'Unionicola (Parasitatax)'],
#  'Unionicola (Pentatax) aculeata': ['Hydracarina',
#   'Unionicolidae',
#   'Unionicola (Pentatax)'],
#  'Unionicola (Pentatax) bonzi': ['Hydracarina',
#   'Unionicolidae',
#   'Unionicola (Pentatax)'],
#  'Unionicola (Pentatax) figuralis': ['Hydracarina',
#   'Unionicolidae',
#   'Unionicola (Pentatax)'],
#  'Unionicola (Pentatax) intermedia': ['Hydracarina',
#   'Unionicolidae',
#   'Unionicola (Pentatax)'],
#  'Unionicola (Unionicola) crassipes': ['Hydracarina',
#   'Unionicolidae',
#   'Unionicola (Unionicola)'],
#  'Unionicola (Unionicola) gracilipalpis': ['Hydracarina',
#   'Unionicolidae',
#   'Unionicola (Unionicola)'],
#  'Unionicola (Unionicola) minor': ['Hydracarina',
#   'Unionicolidae',
#   'Unionicola (Unionicola)'],
#  'Urolepis maritima': ['Hymenoptera', 'Pteromalidae', 'Urolepis'],
#  'Valvata (Cincinna) piscinalis': ['Gastropoda',
#   'Valvatidae',
#   'Valvata (Cincinna)'],
#  'Valvata (Tropidina) macrostoma': ['Gastropoda',
#   'Valvatidae',
#   'Valvata (Tropidina)'],
#  'Valvata (Valvata) cristata': ['Gastropoda',
#   'Valvatidae',
#   'Valvata (Valvata)'],
#  'Vanoyia tenuicornis': ['Diptera', 'Stratiomyidae', 'Vanoyia'],
#  'Vejdovskyella comata': ['Oligochaeta', 'Naididae', 'Vejdovskyella'],
#  'Vejdovskyella intermedia': ['Oligochaeta', 'Naididae', 'Vejdovskyella'],
#  'Velia (Plesiovelia) caprai': ['Hemiptera',
#   'Veliidae',
#   'Velia (Plesiovelia)'],
#  'Velia (Plesiovelia) saulii': ['Hemiptera',
#   'Veliidae',
#   'Velia (Plesiovelia)'],
#  'Ventrosia ventrosa': ['Gastropoda', 'Hydrobiidae', 'Ventrosia'],
#  'Vertigo (Vertigo) antivertigo': ['Gastropoda',
#   'Vertiginidae',
#   'Vertigo (Vertigo)'],
#  'Vertigo (Vertigo) genesii': ['Gastropoda',
#   'Vertiginidae',
#   'Vertigo (Vertigo)'],
#  'Vertigo (Vertigo) geyeri': ['Gastropoda',
#   'Vertiginidae',
#   'Vertigo (Vertigo)'],
#  'Vertigo (Vertigo) lilljeborgi': ['Gastropoda',
#   'Vertiginidae',
#   'Vertigo (Vertigo)'],
#  'Vertigo (Vertigo) moulinsiana': ['Gastropoda',
#   'Vertiginidae',
#   'Vertigo (Vertigo)'],
#  'Vertigo (Vertigo) pygmaea': ['Gastropoda',
#   'Vertiginidae',
#   'Vertigo (Vertigo)'],
#  'Vertigo (Vertigo) substriata': ['Gastropoda',
#   'Vertiginidae',
#   'Vertigo (Vertigo)'],
#  'Vertigo (Vertilla) angustior': ['Gastropoda',
#   'Vertiginidae',
#   'Vertigo (Vertilla)'],
#  'Victorella pavida': ['Ectoprocta', 'Noellidae', 'Victorella'],
#  'Vietsia scutata': ['Hydracarina', 'Hydryphantidae', 'Vietsia'],
#  'Virgatanytarsus arduennensis': ['Diptera',
#   'Chironominae (Tanytarsini)',
#   'Virgatanytarsus'],
#  'Virgatanytarsus triangularis': ['Diptera',
#   'Chironominae (Tanytarsini)',
#   'Virgatanytarsus'],
#  'Viviparus contectus': ['Gastropoda', 'Viviparidae', 'Viviparus'],
#  'Viviparus viviparus': ['Gastropoda', 'Viviparidae', 'Viviparus'],
#  'Wandesia (Wandesia) racovitzai': ['Hydracarina',
#   'Hydryphantidae',
#   'Wandesia (Wandesia)'],
#  'Wettina podagrica': ['Hydracarina', 'Pionidae', 'Wettina'],
#  'Wiedemannia (Chamaedipsia) lota': ['Diptera',
#   'Empididae',
#   'Wiedemannia (Chamaedipsia)'],
#  'Wiedemannia (Philolutra) phantasma': ['Diptera',
#   'Empididae',
#   'Wiedemannia (Philolutra)'],
#  'Wiedemannia (Philolutra) simplex': ['Diptera',
#   'Empididae',
#   'Wiedemannia (Philolutra)'],
#  'Wiedemannia (Pseudowiedemannia) lamellata': ['Diptera',
#   'Empididae',
#   'Wiedemannia (Pseudowiedemannia)'],
#  'Wiedemannia (Wiedemannia) bistigma': ['Diptera',
#   'Empididae',
#   'Wiedemannia (Wiedemannia)'],
#  'Wiedemannia (Wiedemannia) rhynchops': ['Diptera',
#   'Empididae',
#   'Wiedemannia (Wiedemannia)'],
#  'Wierzejskiella elongata': ['Rotifera', 'Dicranophoridae', 'Wierzejskiella'],
#  'Wierzejskiella ricciae': ['Rotifera', 'Dicranophoridae', 'Wierzejskiella'],
#  'Wolga spinifera': ['Rotifera', 'Trichotridae', 'Wolga'],
#  'Wormaldia mediana': ['Trichoptera', 'Philopotamidae', 'Wormaldia'],
#  'Wormaldia occipitalis': ['Trichoptera', 'Philopotamidae', 'Wormaldia'],
#  'Wormaldia subnigra': ['Trichoptera', 'Philopotamidae', 'Wormaldia'],
#  'Xanthoperla apicalis': ['Plecoptera', 'Chloroperlidae', 'Xanthoperla'],
#  'Xenochironomus xenolabis': ['Diptera',
#   'Chironominae (Chironomini)',
#   'Xenochironomus'],
#  'Xenopelopia falcigera': ['Diptera', 'Tanypodinae', 'Xenopelopia'],
#  'Xenopelopia nigricans': ['Diptera', 'Tanypodinae', 'Xenopelopia'],
#  'Ylodes conspersus': ['Trichoptera', 'Leptoceridae', 'Ylodes'],
#  'Ylodes reuteri': ['Trichoptera', 'Leptoceridae', 'Ylodes'],
#  'Ylodes simulans': ['Trichoptera', 'Leptoceridae', 'Ylodes'],
#  'Zalutschia humphriesiae': ['Diptera', 'Orthocladiinae', 'Zalutschia'],
#  'Zavrelia pentatoma': ['Diptera', 'Chironominae (Tanytarsini)', 'Zavrelia'],
#  'Zavreliella marmorata': ['Diptera',
#   'Chironominae (Chironomini)',
#   'Zavreliella'],
#  'Zavrelimyia barbatipes': ['Diptera', 'Tanypodinae', 'Zavrelimyia'],
#  'Zavrelimyia hirtimana': ['Diptera', 'Tanypodinae', 'Zavrelimyia'],
#  'Zavrelimyia melanura': ['Diptera', 'Tanypodinae', 'Zavrelimyia'],
#  'Zavrelimyia nubila': ['Diptera', 'Tanypodinae', 'Zavrelimyia'],
#  'Zonitoides (Zonitoides) nitidus': ['Gastropoda',
#   'Zonitidae',
#   'Zonitoides (Zonitoides)'],
#  'Zschokkea oblonga': ['Hydracarina', 'Hydryphantidae', 'Zschokkea']}

# %%
# test:
# the genus in the key (from the binomial name)
# should fit the genus form the value (third item in the list of phylum, group, genus).

for species in reverse_taxonomy:
    if not species.split()[0] == reverse_taxonomy[species][2].split()[0]:
        print species, reverse_taxonomy[species]
        
# Nothing printed, success.
